# %%
'''
13.1 Word frequency analysis

# %%
'''
Exercise 13.1. Write a program that reads a file, breaks each line into words, strips whitespace and
punctuation from the words, and converts them to lowercase.

# %%
import string
def convert_words(x):
    words=[]
    for lines in open(x):
        words.append(lines.strip())
    words=''.join(words)
    for i in string.punctuation:
        new=words.replace(i,'')
        words=new
    return new.lower().split()

# %%
convert_words('C:/Users/HP/Desktop/rony.txt')
# Out:
# ['i',
#  'am',
#  'rony123gmailcom',
#  'abhishek',
#  'kar',
#  'askmdkmadmada',
#  'asdkbasdjb',
#  'basd',
#  'asddasdasddas',
#  'cjabsdnknakndlanasnansmfansfnasmnanananfanwannsnasf']

# %%
'''
Exercise 13.2. Go to Project Gutenberg (http: // gutenberg. org ) and download your favorite
out-of-copyright book in plain text format.
Modify your program from the previous exercise to read the book you downloaded, skip over the
header information at the beginning of the file, and process the rest of the words as before.
Then modify the program to count the total number of words in the book, and the number of times
each word is used.
Print the number of different words used in the book. Compare different books by different authors,
written in different eras. Which author uses the most extensive vocabulary?

# %%
bear=convert_words('C:/Users/HP/Desktop/bear.txt')

# %%
bear[0:5]
# Out:
# ['a', 'long', 'time', 'ago', 'at']

# %%
clock=convert_words('C:/Users/HP/Desktop/clock.txt')

# %%
len(bear)
# Out:
# 22360

# %%
len(clock)
# Out:
# 58508

# %%
def count(x):
    d=dict()
    for i in x:
        if i not in d:
            d[i]=1
        else:
            d[i]+=1
    return d

# %%
b=count(bear)

# %%
b
# Out:
# {'a': 461,
#  'long': 26,
#  'time': 28,
#  'ago': 6,
#  'at': 121,
#  'seoul': 1,
#  'the': 1507,
#  'capital': 1,
#  'of': 465,
#  'korea': 2,
#  'now': 31,
#  'under': 9,
#  'controlof': 1,
#  'japan': 1,
#  'lived': 3,
#  'king': 38,
#  'and': 719,
#  'queen': 11,
#  'who': 48,
#  'had': 157,
#  'little': 63,
#  'daughter': 4,
#  'calledchonwathe': 1,
#  'princess': 28,
#  'grew': 6,
#  'in': 268,
#  'sunshine': 2,
#  'her': 176,
#  'parents': 1,
#  'love': 4,
#  'untilshe': 1,
#  'reached': 11,
#  'age': 2,
#  'eight': 3,
#  'then': 57,
#  'it': 137,
#  'was': 278,
#  'announced': 1,
#  'that': 237,
#  'accordingto': 1,
#  'custom': 2,
#  'country': 16,
#  'betrothal': 1,
#  'to': 620,
#  'be': 95,
#  'arranged': 1,
#  'by': 97,
#  'thestate': 2,
#  'mother': 16,
#  'led': 9,
#  'into': 49,
#  'beautiful': 19,
#  'garden': 3,
#  'tried': 14,
#  'showthe': 1,
#  'perplexed': 2,
#  'girl': 18,
#  'why': 10,
#  'rules': 3,
#  'court': 3,
#  'required': 3,
#  'kingschild': 1,
#  'should': 13,
#  'married': 2,
#  'for': 163,
#  'sake': 2,
#  'countryso': 1,
#  'fixed': 1,
#  'were': 93,
#  'their': 66,
#  'minds': 1,
#  'on': 101,
#  'this': 91,
#  'subject': 3,
#  'neither': 1,
#  'them': 73,
#  'noticeda': 1,
#  'dark': 7,
#  'fiercelooking': 1,
#  'man': 46,
#  'creeping': 2,
#  'after': 23,
#  'none': 3,
#  'but': 122,
#  'very': 41,
#  'boldman': 1,
#  'would': 44,
#  'have': 66,
#  'dared': 1,
#  'come': 28,
#  'thus': 3,
#  'kings': 3,
#  'private': 1,
#  'grounds': 1,
#  'hefollowed': 1,
#  'with': 195,
#  'fierce': 2,
#  'glances': 1,
#  'every': 25,
#  'movement': 1,
#  'innocent': 2,
#  'pair': 2,
#  'whenthe': 1,
#  'child': 12,
#  'sat': 21,
#  'down': 34,
#  'bench': 1,
#  'watch': 4,
#  'turtledovedrink': 1,
#  'fountain': 1,
#  'crawled': 5,
#  'toward': 22,
#  'knife': 8,
#  'inhis': 4,
#  'teeth': 4,
#  'he': 296,
#  'almost': 10,
#  'upon': 39,
#  'when': 84,
#  'happened': 4,
#  'see': 49,
#  'himbefore': 1,
#  'she': 146,
#  'could': 51,
#  'even': 9,
#  'cry': 5,
#  'help': 17,
#  'ruffian': 1,
#  'stabbed': 2,
#  'twicecourageously': 1,
#  'sprang': 15,
#  'scratchedhis': 1,
#  'face': 17,
#  'drew': 5,
#  'back': 46,
#  'from': 72,
#  'unexpected': 1,
#  'attack': 2,
#  'rushed': 13,
#  'thedefiant': 1,
#  'maiden': 1,
#  'seized': 10,
#  'waist': 1,
#  'carried': 8,
#  'off': 26,
#  'armsjust': 1,
#  'as': 163,
#  'gate': 5,
#  'stopped': 3,
#  'an': 38,
#  'encounter': 3,
#  'helittle': 1,
#  'expectedhe': 1,
#  'found': 22,
#  'himself': 13,
#  'ugly': 11,
#  'grinningbearthe': 1,
#  'placed': 6,
#  'his': 274,
#  'frightened': 4,
#  'burden': 3,
#  'ground': 9,
#  'forhis': 2,
#  'bloody': 2,
#  'huge': 4,
#  'bear': 29,
#  'up': 50,
#  'stillgrinning': 1,
#  'came': 36,
#  'near': 12,
#  'enough': 6,
#  'struck': 10,
#  'him': 101,
#  'such': 16,
#  'blow': 5,
#  'onthe': 2,
#  'head': 27,
#  'went': 11,
#  'sprawling': 3,
#  'flew': 7,
#  'outof': 2,
#  'handthe': 1,
#  'lay': 8,
#  'where': 26,
#  'fallen': 3,
#  'ashen': 1,
#  'turned': 20,
#  'thesetting': 2,
#  'sun': 11,
#  'bruin': 3,
#  'waddled': 6,
#  'over': 29,
#  'pushed': 2,
#  'nose': 6,
#  'tosee': 1,
#  'if': 70,
#  'move': 8,
#  'showed': 7,
#  'no': 47,
#  'sign': 4,
#  'life': 10,
#  'turnedand': 3,
#  'pull': 1,
#  'sleeve': 1,
#  'palace': 13,
#  'chonwawas': 2,
#  'not': 161,
#  'all': 116,
#  'afraid': 12,
#  'rescuer': 3,
#  'followed': 12,
#  'willinglythey': 1,
#  'gone': 16,
#  'far': 7,
#  'they': 188,
#  'met': 8,
#  'guards': 5,
#  'camerushing': 1,
#  'frantic': 2,
#  'haste': 2,
#  'hesitated': 3,
#  'between': 3,
#  'themand': 2,
#  'captain': 4,
#  'laid': 5,
#  'hold': 6,
#  'trotted': 1,
#  'awaychonwa': 1,
#  'told': 17,
#  'father': 9,
#  'rescue': 5,
#  'butonly': 1,
#  'guard': 6,
#  'believed': 4,
#  'part': 5,
#  'tale': 2,
#  'along': 7,
#  'hunt': 2,
#  'trace': 1,
#  'or': 76,
#  'robber': 1,
#  'dropped': 3,
#  'thewhole': 2,
#  'affairthe': 1,
#  'illness': 1,
#  'which': 31,
#  'recovery': 1,
#  'washastened': 1,
#  'sight': 4,
#  'darling': 1,
#  'whom': 6,
#  'given': 3,
#  'aslostthe': 1,
#  'never': 16,
#  'forgot': 2,
#  'shaggy': 1,
#  'deliverer': 1,
#  'looked': 22,
#  'daily': 3,
#  'forher': 1,
#  'return': 11,
#  'passed': 7,
#  'rapidly': 1,
#  'did': 39,
#  'seem': 3,
#  'longtill': 1,
#  'four': 6,
#  'years': 13,
#  'rolled': 6,
#  'away': 27,
#  'according': 1,
#  'customof': 1,
#  'nation': 2,
#  'chonwa': 18,
#  'though': 7,
#  'only': 28,
#  'twelve': 5,
#  'old': 41,
#  'consideredready': 1,
#  'marriageshe': 1,
#  'taken': 2,
#  'inner': 3,
#  'clothed': 2,
#  'like': 32,
#  'woman': 32,
#  'hatefulchanot': 1,
#  'veil': 2,
#  'put': 4,
#  'so': 57,
#  'boys': 15,
#  'seeher': 1,
#  'playmate': 2,
#  'harsh': 1,
#  'governess': 1,
#  'scolded': 1,
#  'allthe': 2,
#  'poor': 23,
#  'often': 4,
#  'wished': 4,
#  'herself': 8,
#  'deadamong': 1,
#  'former': 1,
#  'boy': 35,
#  'friends': 3,
#  'young': 12,
#  'prince': 15,
#  'consideredher': 1,
#  'best': 6,
#  'one': 47,
#  'day': 22,
#  'stole': 1,
#  'unseen': 1,
#  'hergoverness': 1,
#  'boyprince': 1,
#  'whose': 4,
#  'name': 8,
#  'mousan': 11,
#  'werefound': 1,
#  'out': 48,
#  'two': 17,
#  'days': 9,
#  'later': 5,
#  'banished': 2,
#  'betrothed': 2,
#  'sixty': 1,
#  'year': 2,
#  'seen': 10,
#  'herprotests': 1,
#  'vain': 5,
#  'considered': 1,
#  'honorable': 2,
#  'marriagearranged': 1,
#  'state': 6,
#  'benefit': 1,
#  'people': 38,
#  'imaginechonwas': 1,
#  'misery': 1,
#  'beheld': 3,
#  'hamkiengwhich': 1,
#  'made': 31,
#  'think': 7,
#  'dead': 5,
#  'pig': 12,
#  'too': 16,
#  'andsnored': 1,
#  'loudly': 6,
#  'daytime': 1,
#  'being': 8,
#  'amused': 2,
#  'whenhe': 1,
#  'walked': 15,
#  'fat': 5,
#  'porker': 1,
#  'cried': 11,
#  'butshe': 1,
#  'stop': 1,
#  'marriage': 3,
#  'arrangements': 1,
#  'last': 15,
#  'weddingday': 1,
#  'arrivedthe': 1,
#  'beautifully': 1,
#  'decorated': 1,
#  'guests': 2,
#  'allassembled': 1,
#  'just': 14,
#  'gave': 12,
#  'command': 1,
#  'ceremony': 2,
#  'begina': 1,
#  'loud': 1,
#  'growl': 1,
#  'heard': 19,
#  'coming': 9,
#  'entrance': 5,
#  'priest': 1,
#  'stoppedhis': 1,
#  'preparations': 2,
#  'fled': 13,
#  'wonder': 7,
#  'instant': 4,
#  'theroom': 2,
#  'great': 50,
#  'chonwas': 4,
#  'friend': 12,
#  'fainted': 1,
#  'kingin': 1,
#  'trying': 4,
#  'stumbled': 1,
#  'headlong': 2,
#  'hammiesothey': 1,
#  'called': 8,
#  'courtdrawing': 1,
#  'sword': 6,
#  'awkward': 1,
#  'thrustat': 1,
#  'beast': 17,
#  'raised': 3,
#  'paw': 5,
#  'smote': 1,
#  'headrolling': 1,
#  'barrel': 1,
#  'company': 7,
#  'hadscattered': 1,
#  'hidthe': 1,
#  'delighted': 5,
#  'atight': 1,
#  'hug': 1,
#  'venturing': 1,
#  'hidingplaces': 1,
#  'moreastonished': 1,
#  'than': 27,
#  'before': 30,
#  'still': 10,
#  'more': 24,
#  'amazed': 1,
#  'chonwabestride': 1,
#  'grinning': 2,
#  'ride': 1,
#  'thegarden': 1,
#  'rode': 2,
#  'past': 4,
#  'soldiers': 11,
#  'busy': 2,
#  'street': 2,
#  'aneighboring': 2,
#  'forestthe': 1,
#  'wild': 9,
#  'grief': 1,
#  'unlucky': 1,
#  'hammiechagrined': 1,
#  'brides': 1,
#  'escape': 5,
#  'bit': 5,
#  'finger': 4,
#  'nails': 1,
#  'rewardwas': 1,
#  'offered': 5,
#  'hand': 11,
#  'princesswas': 1,
#  'promised': 1,
#  'bring': 6,
#  'safely': 3,
#  'homemeanwhile': 1,
#  'dismounted': 1,
#  'forest': 3,
#  'became': 21,
#  'aware': 1,
#  'ayoung': 1,
#  'dressed': 4,
#  'white': 5,
#  'ablack': 1,
#  'broadbrimmed': 1,
#  'hat': 2,
#  'once': 14,
#  'recognized': 3,
#  'banishedprincei': 1,
#  'cannot': 9,
#  'tell': 19,
#  'you': 203,
#  'said': 56,
#  'how': 18,
#  'thankful': 2,
#  'i': 170,
#  'am': 28,
#  'find': 11,
#  'ihave': 3,
#  'waited': 3,
#  'these': 19,
#  'months': 2,
#  'wondering': 2,
#  'what': 31,
#  'become': 4,
#  'youbruin': 1,
#  'gathered': 7,
#  'children': 59,
#  'arms': 8,
#  'opening': 5,
#  'hermouth': 1,
#  'began': 29,
#  'talkmy': 1,
#  'dear': 16,
#  'land': 9,
#  'morebeautiful': 1,
#  'any': 44,
#  'ever': 11,
#  'imagined': 1,
#  'play': 3,
#  'is': 99,
#  'work': 48,
#  'andwork': 1,
#  'we': 57,
#  'shall': 28,
#  'proceed': 3,
#  'eastern': 1,
#  'mountains': 4,
#  'thentrace': 1,
#  'river': 10,
#  'naktongkang': 1,
#  'sea': 2,
#  'finally': 6,
#  'settledown': 1,
#  'wonderful': 5,
#  'home': 15,
#  'ourselvesbut': 1,
#  'words': 12,
#  'comfort': 3,
#  'interrupted': 2,
#  'appearance': 3,
#  'afunnylooking': 1,
#  'eyebrows': 1,
#  'thembraided': 1,
#  'hung': 2,
#  'ears': 2,
#  'spectacles': 1,
#  'thumband': 1,
#  'held': 7,
#  'highly': 2,
#  'polished': 2,
#  'stone': 10,
#  'explained': 6,
#  'washumok': 1,
#  'doctor': 10,
#  'cure': 5,
#  'diseasesthe': 1,
#  'growled': 3,
#  'begged': 9,
#  'eyeswhich': 1,
#  'been': 33,
#  'weakened': 1,
#  'wearing': 1,
#  'whereupon': 1,
#  'slappedhis': 1,
#  'knees': 3,
#  'gaze': 1,
#  'suddenly': 9,
#  'felta': 1,
#  'peculiar': 4,
#  'dizziness': 1,
#  'felt': 4,
#  'eyes': 31,
#  'getting': 4,
#  'larger': 3,
#  'andthe': 6,
#  'kept': 11,
#  'bigger': 1,
#  'biggerand': 2,
#  'knew': 12,
#  'moreshe': 1,
#  'faintedmousan': 1,
#  'caught': 10,
#  'fell': 13,
#  'lifted': 5,
#  'right': 13,
#  'andsmote': 1,
#  'heavy': 3,
#  'grass': 6,
#  'hisstone': 1,
#  'lodged': 1,
#  'nearby': 2,
#  'tree': 7,
#  'took': 20,
#  'some': 26,
#  'revive': 1,
#  'girlmeanwhile': 1,
#  'recovered': 5,
#  'sufficiently': 1,
#  'sit': 1,
#  'apitifullooking': 1,
#  'object': 2,
#  'bloodshot': 1,
#  'hair': 6,
#  'stood': 20,
#  'upas': 1,
#  'bad': 6,
#  'dream': 1,
#  'oh': 13,
#  'give': 15,
#  'me': 32,
#  'my': 77,
#  'myprecious': 1,
#  'moaned': 2,
#  'doleful': 1,
#  'quackmouwou': 1,
#  'showing': 2,
#  'raising': 3,
#  'terriblepaw': 1,
#  'silentbut': 1,
#  'angered': 1,
#  'false': 1,
#  'doctors': 3,
#  'wicked': 8,
#  'trick': 1,
#  'herushed': 1,
#  'grabbed': 1,
#  'eyebrow': 1,
#  'whiskers': 1,
#  'dragged': 6,
#  'offhowlingscarcely': 1,
#  'disappeared': 7,
#  'view': 7,
#  'others': 13,
#  'thequack': 1,
#  'tiger': 1,
#  'bore': 1,
#  'theground': 1,
#  'mouth': 23,
#  'prevent': 4,
#  'himfrom': 2,
#  'yelling': 2,
#  'helpnow': 1,
#  'hissed': 1,
#  'furious': 2,
#  'humok': 1,
#  'twice': 2,
#  'strong': 4,
#  'anyordinary': 1,
#  'teach': 6,
#  'thing': 14,
#  'struggled': 1,
#  'toescape': 1,
#  'planted': 1,
#  'foot': 4,
#  'neck': 7,
#  'itthere': 1,
#  'till': 18,
#  'senseless': 1,
#  'cautiously': 2,
#  'villain': 1,
#  'around': 5,
#  'lestsome': 1,
#  'victim': 2,
#  'denwhen': 1,
#  'revived': 3,
#  'completely': 4,
#  'persuaded': 2,
#  'tomount': 1,
#  'again': 35,
#  'guessed': 1,
#  'there': 37,
#  'wasanything': 1,
#  'wrong': 1,
#  'other': 24,
#  'charge': 9,
#  'asked': 12,
#  'herwhere': 1,
#  'merely': 2,
#  'replied': 7,
#  'punish': 3,
#  'thedoctorthey': 1,
#  'saw': 31,
#  'snake': 6,
#  'charming': 1,
#  'littlebird': 2,
#  'bird': 21,
#  'its': 18,
#  'perch': 3,
#  'screamingand': 1,
#  'flapping': 2,
#  'wings': 4,
#  'terror': 6,
#  'reptileand': 1,
#  'deadly': 2,
#  'grateful': 1,
#  'itsrescuers': 1,
#  'perched': 1,
#  'shoulder': 3,
#  'rubbed': 2,
#  'itssmooth': 1,
#  'feathers': 5,
#  'against': 11,
#  'cheek': 1,
#  'while': 23,
#  'wiggled': 1,
#  'dieso': 1,
#  'queer': 1,
#  'trio': 1,
#  'through': 27,
#  'woods': 4,
#  'chonwasshoulder': 1,
#  'bears': 1,
#  'surprised': 7,
#  'anddelighted': 1,
#  'thatched': 1,
#  'shanty': 1,
#  'asign': 1,
#  'rest': 9,
#  'wearydo': 1,
#  'let': 23,
#  'us': 31,
#  'here': 15,
#  'catches': 1,
#  'eager': 4,
#  'shedismounted': 1,
#  'approached': 9,
#  'house': 17,
#  'peered': 2,
#  'herdelight': 1,
#  'lying': 7,
#  'couch': 1,
#  'readingshe': 1,
#  'knocked': 1,
#  'gently': 3,
#  'smiling': 3,
#  'holding': 7,
#  'glassof': 1,
#  'wine': 5,
#  'thirsty': 1,
#  'about': 49,
#  'take': 15,
#  'thedrink': 1,
#  'opened': 10,
#  'behold': 1,
#  'cloven': 1,
#  'tongue': 3,
#  'dartedoutchonwa': 1,
#  'glass': 2,
#  'fearthe': 1,
#  'serpent': 1,
#  'sawher': 1,
#  'mistake': 1,
#  'changed': 7,
#  'pursueherthe': 1,
#  'distance': 6,
#  'thesnake': 1,
#  'allits': 1,
#  'strength': 3,
#  'open': 6,
#  'reptile': 2,
#  'itstiny': 1,
#  'serpents': 1,
#  'prevented': 2,
#  'bitingbut': 1,
#  'frail': 1,
#  'received': 6,
#  'intended': 1,
#  'fellto': 1,
#  'agony': 1,
#  'othersmouwou': 1,
#  'quickly': 8,
#  'arrived': 1,
#  'scene': 3,
#  'danger': 4,
#  'angry': 9,
#  'fire': 4,
#  'smotethe': 1,
#  'terrible': 11,
#  'crushing': 1,
#  'unable': 1,
#  'tofind': 2,
#  'gallant': 1,
#  'onfinally': 1,
#  'pretty': 3,
#  'resting': 1,
#  'place': 13,
#  'brook': 2,
#  'thatgurgled': 1,
#  'sang': 7,
#  'sweet': 3,
#  'song': 2,
#  'night': 18,
#  'goodmother': 1,
#  'tired': 4,
#  'patch': 1,
#  'moss': 1,
#  'herto': 1,
#  'sleepwhen': 1,
#  'awoke': 4,
#  'much': 21,
#  'refreshed': 1,
#  'inquired': 4,
#  'aboutmousanthe': 1,
#  'worrying': 1,
#  'shesaid': 1,
#  'do': 61,
#  'afraidill': 1,
#  'go': 24,
#  'search': 4,
#  'stay': 4,
#  'thisspot': 1,
#  'believe': 10,
#  'everything': 5,
#  'hear': 8,
#  'saying': 5,
#  'shelumbered': 1,
#  'sightno': 2,
#  'sooner': 4,
#  'bearmother': 1,
#  'wounded': 3,
#  'camecrawling': 1,
#  'maid': 1,
#  'dying': 5,
#  'sobbed': 2,
#  'andi': 2,
#  'want': 9,
#  'good': 30,
#  'thebirds': 1,
#  'voice': 10,
#  'faint': 1,
#  'wide': 4,
#  'deathstareoh': 1,
#  'must': 24,
#  'die': 2,
#  'saved': 4,
#  'thebird': 2,
#  'saving': 1,
#  'poison': 4,
#  'doing': 5,
#  'quicklyat': 1,
#  'calling': 4,
#  'sweetly': 2,
#  'mushroomsmushrooms': 1,
#  'sure': 4,
#  'diseases': 1,
#  'way': 18,
#  'gentle': 1,
#  'canhelp': 1,
#  'deliciouschonwa': 1,
#  'strange': 10,
#  'humpbacked': 1,
#  'scarcely': 4,
#  'three': 7,
#  'feettall': 1,
#  'littlechoirboy': 1,
#  'dish': 1,
#  'dozen': 3,
#  'mushrooms': 5,
#  'hotand': 1,
#  'roasted': 1,
#  'butter': 1,
#  'salt': 1,
#  'filled': 7,
#  'air': 5,
#  'afragrance': 1,
#  'waterbut': 1,
#  'remembering': 1,
#  'fooled': 2,
#  'afraidwho': 1,
#  'are': 53,
#  'demanded': 3,
#  'chonwai': 1,
#  'cook': 6,
#  'bowing': 3,
#  'low': 4,
#  'cooked': 1,
#  'yourfather': 1,
#  'many': 22,
#  'tasted': 1,
#  'dishes': 1,
#  'cookingfor': 1,
#  'try': 5,
#  'cooking': 1,
#  'acts': 1,
#  'medicinewith': 1,
#  'consent': 2,
#  'thrust': 3,
#  'particle': 1,
#  'birdsthroat': 1,
#  'instantly': 3,
#  'chirruped': 1,
#  'withdelightnevertheless': 1,
#  'hunchback': 4,
#  'mikado': 2,
#  'thesnakewomans': 1,
#  'slave': 6,
#  'turnedinto': 1,
#  'food': 3,
#  'cures': 1,
#  'poisoned': 1,
#  'acted': 1,
#  'asan': 1,
#  'antidote': 1,
#  'knowing': 7,
#  'lawsof': 1,
#  'chemistry': 1,
#  'well': 17,
#  'asfine': 1,
#  'medicine': 1,
#  'helped': 1,
#  'appetizing': 1,
#  'dainties': 1,
#  'soonshe': 1,
#  'drowsy': 1,
#  'kicked': 2,
#  'heelsin': 1,
#  'danced': 1,
#  'joy': 2,
#  'shouted': 8,
#  'beenpromised': 1,
#  'straight': 4,
#  'evilwoman': 1,
#  'succeed': 2,
#  'destroying': 2,
#  'lifeha': 1,
#  'ha': 4,
#  'will': 31,
#  'soon': 24,
#  'notclever': 1,
#  'already': 6,
#  'feel': 6,
#  'hump': 4,
#  'gettingstraight': 1,
#  'mouwou': 4,
#  'moment': 11,
#  'appeared': 12,
#  'tonguehung': 1,
#  'red': 9,
#  'heat': 1,
#  'breast': 4,
#  'covered': 4,
#  'flaked': 1,
#  'foamher': 1,
#  'blazed': 1,
#  'sounded': 2,
#  'rumbling': 1,
#  'thunderthe': 1,
#  'cooks': 1,
#  'tune': 2,
#  'mirth': 1,
#  'wails': 1,
#  'mercy': 4,
#  'hishair': 1,
#  'end': 10,
#  'jaws': 7,
#  'relaxed': 1,
#  'swelled': 2,
#  'outyes': 1,
#  'ill': 7,
#  'straighten': 1,
#  'miserable': 4,
#  'shelifted': 1,
#  'brought': 8,
#  'force': 4,
#  'thehumpouch': 1,
#  'ouch': 1,
#  'yelled': 2,
#  'dancer': 1,
#  'thrustout': 1,
#  'humpchested': 1,
#  'nowthere': 1,
#  'henceforth': 2,
#  'youll': 2,
#  'follow': 6,
#  'your': 47,
#  'wonthave': 1,
#  'carry': 3,
#  'morewhile': 1,
#  'dealing': 1,
#  'furiouslypicking': 1,
#  'swollen': 1,
#  'picked': 4,
#  'until': 6,
#  'holewas': 1,
#  'skin': 2,
#  'immediately': 5,
#  'ran': 17,
#  'inthe': 7,
#  'scratch': 1,
#  'armseveral': 1,
#  'snakes': 2,
#  'killed': 10,
#  'shescratched': 1,
#  'twenty': 3,
#  'killedthe': 1,
#  'entirely': 3,
#  'growing': 4,
#  'mothermade': 1,
#  'cozy': 1,
#  'bed': 9,
#  'leaves': 3,
#  'bade': 2,
#  'prayer': 2,
#  'forthe': 2,
#  'safety': 4,
#  'asleepin': 1,
#  'morning': 5,
#  'started': 7,
#  'alittle': 1,
#  'flight': 1,
#  'exercise': 1,
#  'returned': 9,
#  'informationthat': 1,
#  'pain': 8,
#  'following': 4,
#  'rolling': 3,
#  'groundapparently': 1,
#  'weak': 1,
#  'stand': 3,
#  'thought': 19,
#  'twistedround': 1,
#  'because': 12,
#  'beforehe': 1,
#  'spent': 2,
#  'greater': 2,
#  'overtrying': 1,
#  'twist': 2,
#  'waswhen': 1,
#  'untwist': 1,
#  'himill': 1,
#  'pinhead': 1,
#  ...}

# %%
c=count(clock)

# %%
c
# Out:
# {'chapter': 8,
#  'iour': 1,
#  'gondola': 23,
#  'far': 25,
#  'out': 109,
#  'on': 331,
#  'the': 3598,
#  'lagoon': 3,
#  'hardly': 18,
#  'moved': 4,
#  'but': 287,
#  'neither': 6,
#  'jacquelinenor': 1,
#  'i': 1635,
#  'under': 26,
#  'red': 6,
#  'and': 1162,
#  'white': 12,
#  'striped': 3,
#  'awning': 5,
#  'cared': 6,
#  'much': 39,
#  'pietroeven': 1,
#  'dared': 6,
#  'to': 1600,
#  'light': 24,
#  'a': 1077,
#  'cigarettesilvergray': 1,
#  'dome': 5,
#  'campanile': 6,
#  'spire': 3,
#  'gleamed': 1,
#  'through': 35,
#  'golden': 5,
#  'hazethat': 1,
#  'hung': 3,
#  'over': 57,
#  'enchanted': 2,
#  'city': 14,
#  'great': 50,
#  'stillness': 2,
#  'was': 697,
#  'all–onlythe': 1,
#  'ripple': 2,
#  'of': 1619,
#  'pietro’s': 2,
#  'lazy': 1,
#  'oar': 3,
#  'faintly': 4,
#  'very': 75,
#  'bellschiming“i': 1,
#  'have': 378,
#  'dreamed': 5,
#  'it”': 9,
#  'said': 170,
#  'jacqueline': 94,
#  '“only': 2,
#  'dreams': 6,
#  'were': 218,
#  'suchfutile': 1,
#  'things': 13,
#  'compared': 1,
#  'with': 391,
#  'reality': 1,
#  'close': 6,
#  'my': 502,
#  'eyes': 46,
#  'open': 35,
#  'themquickly': 1,
#  'am': 88,
#  'afraid': 6,
#  'it': 701,
#  'will': 133,
#  'all': 129,
#  'be': 289,
#  'blown': 3,
#  'away': 30,
#  'vanish': 2,
#  'in': 861,
#  'singlemoment': 1,
#  'there': 184,
#  'is': 553,
#  'your': 125,
#  'dear': 53,
#  'venice–the': 1,
#  'green': 4,
#  'garden': 23,
#  'upthere': 1,
#  'riva': 5,
#  'basking': 1,
#  'sunlight': 3,
#  'rosy': 1,
#  'palace': 76,
#  'thered': 1,
#  'orange': 2,
#  'sails': 1,
#  'drifting': 2,
#  'slowly': 30,
#  'along': 13,
#  'we': 287,
#  'shall': 77,
#  'return': 20,
#  'thepiazza': 1,
#  'presently': 15,
#  'st': 232,
#  'mark’s': 2,
#  'pigeons': 2,
#  'thewhite': 1,
#  'palaces': 13,
#  'oh': 6,
#  'not': 464,
#  'false': 5,
#  'note': 9,
#  'destroy': 1,
#  'perfectcharm': 1,
#  'venice': 85,
#  'one”i': 1,
#  'aroused': 5,
#  'myself': 65,
#  'while': 32,
#  'had': 526,
#  'been': 111,
#  'intoxicated': 2,
#  'beautyof': 1,
#  'beauty': 14,
#  'mustsay': 2,
#  'something': 27,
#  'prosaic': 2,
#  'or': 172,
#  'should': 118,
#  'forgetting': 2,
#  'myself“oh': 1,
#  'favored': 1,
#  'gods”': 1,
#  'murmured': 6,
#  '“to': 8,
#  'dead': 10,
#  'unpleasant': 2,
#  'sightsand': 1,
#  'sounds': 2,
#  'yet': 33,
#  'paradise': 3,
#  'even': 47,
#  'this': 290,
#  'arethey': 3,
#  'quite': 68,
#  'shut': 4,
#  'look': 48,
#  'penny': 4,
#  'steamer': 7,
#  'making': 8,
#  'its': 82,
#  'blatantway': 1,
#  'from': 156,
#  'molo': 9,
#  'giudecca': 7,
#  'that': 862,
#  'faroff': 3,
#  'rumble': 1,
#  'theexpress': 1,
#  'crossing': 4,
#  'long': 50,
#  'bridge': 7,
#  'mestre': 2,
#  'whew': 1,
#  'that’s': 3,
#  'thetwelveo’clock': 1,
#  'whistle': 1,
#  'at': 453,
#  'arsenal': 1,
#  'you': 767,
#  'three': 40,
#  'notes': 5,
#  'ofprogress': 1,
#  'civilization': 1,
#  'hopes”jacqueline': 1,
#  'turned': 36,
#  'her': 221,
#  'seat': 14,
#  'looked': 80,
#  'me': 472,
#  'curiously“my': 1,
#  'richard': 2,
#  'answer': 16,
#  'one': 211,
#  'question”“gladly': 1,
#  'if': 204,
#  'too': 50,
#  'difficult': 14,
#  'don’t': 10,
#  'forget': 9,
#  'jacquelinevenice': 1,
#  'exactly': 3,
#  'an': 159,
#  'intellectual': 2,
#  'center”“then': 1,
#  'tell': 48,
#  'please': 10,
#  'why': 59,
#  'when': 112,
#  'new': 19,
#  'york': 8,
#  'hardlytwo': 1,
#  'months': 2,
#  'ago': 22,
#  'talked': 1,
#  'so': 181,
#  'charmingly': 1,
#  'venetian': 18,
#  'skies': 2,
#  'andstill': 1,
#  'lagoons': 1,
#  'made': 75,
#  'for': 467,
#  'them': 72,
#  'now': 98,
#  'amat': 1,
#  'last': 70,
#  'wonderful': 21,
#  'lagooninstead': 1,
#  'helping': 2,
#  'love': 51,
#  'sympathizing': 1,
#  'youinsist': 1,
#  'horrible': 2,
#  'clash–things': 1,
#  'would': 162,
#  'gladly': 3,
#  'forgetfor': 1,
#  'happy': 6,
#  'moment”“because”': 1,
#  'answered': 43,
#  'gravely': 4,
#  '“i': 51,
#  'must': 98,
#  'allow': 7,
#  'thatone': 1,
#  'moment': 33,
#  'lifetime”“really': 1,
#  'understand': 28,
#  'you“she': 1,
#  'frankly–too': 1,
#  'frankly–that': 1,
#  'trouble': 10,
#  'hesitatedin': 1,
#  'spite': 9,
#  'flimsy': 2,
#  'excuses': 2,
#  'aunt': 15,
#  'suspiciously': 4,
#  'erected': 2,
#  'hadbrought': 1,
#  'alone': 12,
#  'here': 46,
#  'allowmyself': 1,
#  'may': 73,
#  'add': 2,
#  'hear': 20,
#  'laugh': 5,
#  'delicious': 3,
#  'scornmy': 1,
#  'reasons': 3,
#  'hesitated': 5,
#  'sometimes': 7,
#  'felt': 16,
#  'she': 193,
#  'butif': 1,
#  'question': 12,
#  'truthfully': 2,
#  'risked': 1,
#  'cruel': 4,
#  'awakening“do': 1,
#  'know': 87,
#  'how': 55,
#  'living': 6,
#  'venice”': 7,
#  'asked': 74,
#  'presentlywith': 1,
#  'apparent': 1,
#  'irrelevance“three': 1,
#  'years': 33,
#  'not”“that': 1,
#  'time': 56,
#  'dreaming': 1,
#  'loafing': 1,
#  'isn’t': 2,
#  'it”“yes”': 1,
#  'lagoon“and': 1,
#  'seems': 12,
#  'manly': 3,
#  'strenuous': 3,
#  'life': 26,
#  'man': 67,
#  'of–shallwe': 1,
#  'say–thirty': 1,
#  'age': 2,
#  'spend': 3,
#  'rocking': 1,
#  'himself': 42,
#  'tosleep': 2,
#  'as': 361,
#  'gondola”“no”': 1,
#  'laughed': 17,
#  'nervously': 2,
#  '“hardly': 1,
#  'life”“such': 1,
#  'that”': 14,
#  'persisted': 3,
#  '“must': 2,
#  'contrast': 3,
#  'rather': 23,
#  'unfavorablywith': 1,
#  'lives': 4,
#  'men': 18,
#  'example”“i': 1,
#  'suppose': 23,
#  'one’s': 17,
#  'well': 49,
#  'venice”i': 2,
#  'bitterly“one': 1,
#  'gets': 3,
#  'up': 94,
#  'ten”': 1,
#  '“one': 3,
#  'has': 103,
#  'coffee': 5,
#  'bed': 7,
#  'dawdlesover': 1,
#  'papers': 4,
#  'gentle': 6,
#  'walk': 12,
#  'till': 9,
#  'twelve–to': 1,
#  'gardenperhaps–oh': 1,
#  'can': 78,
#  'miles': 2,
#  'though': 33,
#  'most': 40,
#  'tourists': 6,
#  'thinknot': 1,
#  'twelve': 24,
#  'breakfast': 3,
#  'florian’s': 4,
#  'piazza': 17,
#  'smokeperhaps': 1,
#  'row': 10,
#  'lido': 1,
#  'swim': 1,
#  'summer': 3,
#  'five': 18,
#  'anotherlong': 1,
#  'smoke': 5,
#  'incidentally': 1,
#  'drink': 3,
#  'again': 59,
#  'theband': 1,
#  'seven': 18,
#  'dinner': 4,
#  'grundewald': 2,
#  'momentous': 1,
#  'affair': 5,
#  'onehesitates': 1,
#  'ten': 38,
#  'minutes': 18,
#  'menu': 1,
#  'then': 112,
#  'another': 17,
#  'thelagoon': 1,
#  'stars': 5,
#  'lights': 5,
#  'distance': 5,
#  'andin': 2,
#  'herd': 1,
#  'splitting': 1,
#  'their': 44,
#  'gloves': 1,
#  'inecstasy': 1,
#  'efforts': 5,
#  'tenor': 1,
#  'robusto': 1,
#  'balconies': 2,
#  'thegrand': 3,
#  'hotel': 16,
#  'wicked': 2,
#  'dreamless': 1,
#  'slumber': 1,
#  'next': 19,
#  'morning': 19,
#  'thesame': 1,
#  'thing': 24,
#  'again”jacqueline': 1,
#  'gasped': 1,
#  'curious': 17,
#  'intentness': 2,
#  'wasuneasy': 1,
#  'gaze': 3,
#  'knew': 26,
#  'noting': 1,
#  'ruthlessly': 1,
#  'wasgetting': 1,
#  'fat“it': 1,
#  'keep': 25,
#  'fit': 5,
#  'pleaded“and': 1,
#  'really': 33,
#  'done': 24,
#  'years”': 1,
#  'lastalmost': 1,
#  'admiration': 2,
#  'strange': 15,
#  'animal': 1,
#  'doing': 12,
#  'clevertricks“for': 1,
#  'barring': 1,
#  'flights': 1,
#  'london': 6,
#  'january': 1,
#  'andfebruary': 1,
#  'few': 32,
#  'weeks': 9,
#  'tyrol': 1,
#  'during': 6,
#  'july': 1,
#  'august”': 1,
#  'ianswered': 1,
#  'steadily“and': 1,
#  'like': 41,
#  'still': 39,
#  'wonderingly“i': 1,
#  'never': 39,
#  'imagine': 9,
#  'liking': 2,
#  'despised': 2,
#  'myselfsince': 1,
#  'tuesday”“since': 1,
#  'tuesday”': 1,
#  'echoed': 4,
#  'blushed': 1,
#  'tuesdaythat': 1,
#  'arrived': 4,
#  '“but': 20,
#  'are': 201,
#  'notanswering': 1,
#  'first': 58,
#  'question”“i': 1,
#  'answering': 3,
#  'roundabout': 2,
#  'way”': 1,
#  'replied': 31,
#  'dreamily': 3,
#  'quiteabruptly': 1,
#  '“you': 22,
#  'didn’t': 4,
#  'until': 36,
#  'oxford': 3,
#  'did': 88,
#  'you”“no”“i': 1,
#  'sent': 14,
#  'eton': 1,
#  'sickly': 1,
#  'timid': 1,
#  'little': 89,
#  'chap': 3,
#  'fourteeni': 1,
#  'lonely': 2,
#  'mother': 3,
#  'ishould': 4,
#  'good': 26,
#  'other': 64,
#  'boys': 3,
#  'shout': 4,
#  'play': 13,
#  'talkwith': 1,
#  'american': 7,
#  'accent': 3,
#  'chained': 1,
#  'priggish': 1,
#  'englishtutor': 1,
#  'who': 68,
#  'took': 33,
#  'solemn': 3,
#  'walks': 2,
#  'park': 1,
#  'recreation': 1,
#  'washardly': 1,
#  'any': 93,
#  'better': 16,
#  'off': 20,
#  'than': 71,
#  'palefaced': 1,
#  'idiots': 1,
#  'see': 80,
#  'marchingabout': 1,
#  'rome': 5,
#  'palermo': 1,
#  'two': 82,
#  'by': 157,
#  'dressed': 3,
#  'ridiculous': 2,
#  'uniforms': 1,
#  'ofbroadcloth': 1,
#  'carrying': 1,
#  'canes–not': 1,
#  'many': 17,
#  'ofthem': 4,
#  'only': 67,
#  'slovenly': 1,
#  'priest': 8,
#  'keeper': 1,
#  'himselfthink': 1,
#  'held': 22,
#  'baseball': 1,
#  'fist': 3,
#  'thatkind': 1,
#  'youngster': 2,
#  'set': 18,
#  'down': 59,
#  'midst': 2,
#  'half': 34,
#  'thousand': 14,
#  'lusty': 1,
#  'youngenglish': 1,
#  'schoolboys': 1,
#  'that”“poor': 1,
#  'homesick': 1,
#  'boy”': 1,
#  '“and': 17,
#  'then”“just': 1,
#  'being': 19,
#  'shunned': 1,
#  'moping': 1,
#  'solitary': 1,
#  'rows': 3,
#  'onthe': 13,
#  'river': 1,
#  'bad': 7,
#  'boy': 12,
#  'years–just': 1,
#  'stretch': 1,
#  'ofthat': 4,
#  'sort': 4,
#  'public': 10,
#  'school“at': 1,
#  'pretty': 3,
#  'same': 13,
#  'pulled': 6,
#  'listlesssort': 1,
#  'fashion': 4,
#  'got': 1,
#  'degree': 2,
#  'habits': 5,
#  'boyhood': 1,
#  'told': 45,
#  'ifound': 1,
#  'harder': 1,
#  'ever': 8,
#  'get': 18,
#  'into': 109,
#  'found': 47,
#  'more': 100,
#  'andmore': 1,
#  'mere': 3,
#  'spectator': 1,
#  'life–not': 1,
#  'existence': 6,
#  'nor': 13,
#  'goodfoundation': 1,
#  'begin': 10,
#  'duties': 1,
#  'with”“i': 1,
#  'think': 50,
#  'not”': 10,
#  'severely': 3,
#  'pity': 2,
#  'thelonely': 1,
#  'no': 142,
#  'mercy': 3,
#  'because': 36,
#  'youidled': 1,
#  'college': 1,
#  'liked': 2,
#  'came': 30,
#  'idle': 6,
#  'awaythe': 1,
#  'rest': 10,
#  'life”': 1,
#  'some': 64,
#  'scorn“well': 1,
#  'deliberate': 4,
#  'patiently': 8,
#  '“no': 4,
#  'iwent': 1,
#  'back': 35,
#  'america': 8,
#  'face': 32,
#  'myfather': 1,
#  'least': 30,
#  'he': 643,
#  'taken': 30,
#  'tospeak': 2,
#  'hearttoheart': 1,
#  'way': 63,
#  'father': 15,
#  'soi': 1,
#  'needn’t': 2,
#  'expatiate': 1,
#  'his': 400,
#  'virtues”jacqueline': 1,
#  'smiled': 9,
#  'malice': 1,
#  'hovered': 2,
#  'lips': 11,
#  'mineamerican': 1,
#  'women': 7,
#  'supposed': 4,
#  'demand': 5,
#  'husbands': 2,
#  'andfathers': 1,
#  'they': 93,
#  'respect': 2,
#  'fathers': 2,
#  'toilthat': 1,
#  'primly“i': 1,
#  'always': 20,
#  'interesting': 11,
#  'lovesyou': 1,
#  'ambition': 5,
#  'bitterdisappointment': 1,
#  'often': 7,
#  'spoken': 9,
#  'me”“yes': 1,
#  'yes”': 6,
#  'hurriedly': 3,
#  'doubt': 21,
#  'loves': 4,
#  'own': 30,
#  'fashionbut': 1,
#  'each': 52,
#  'after': 65,
#  'landed': 3,
#  'fromengland': 1,
#  'called': 18,
#  'office': 6,
#  'andasked': 1,
#  'without': 44,
#  'preliminaries': 1,
#  'what': 91,
#  'thought': 50,
#  'toldhim': 1,
#  'hadn’t': 1,
#  'idea': 7,
#  'thumped': 2,
#  'deskand': 1,
#  'roared': 1,
#  '‘so': 1,
#  'young': 14,
#  'turn': 12,
#  'she’smammied': 1,
#  'fool': 8,
#  'english': 7,
#  'education': 1,
#  'andenglish': 1,
#  'it’s': 4,
#  'go': 59,
#  'germany': 1,
#  'stay': 7,
#  'twoyears': 3,
#  'come': 46,
#  'chemist': 4,
#  'want': 7,
#  'help': 18,
#  'factory’“i': 1,
#  'opposing': 1,
#  'him': 203,
#  'relieved': 1,
#  'ofhis': 4,
#  'presence': 5,
#  'check': 2,
#  'handed': 3,
#  'shook': 14,
#  'himdutifully': 1,
#  'hand': 45,
#  '‘goodby’': 1,
#  '‘and': 2,
#  'say': 43,
#  'imean': 1,
#  'aren’t': 1,
#  'bother': 3,
#  'backat': 1,
#  'all’': 1,
#  'engaged': 2,
#  'passage': 10,
#  'bremen”“the': 1,
#  'about”': 2,
#  'looking': 21,
#  'watch“i': 1,
#  'dare': 11,
#  'point': 9,
#  'ofview': 1,
#  'went': 26,
#  'berlin': 1,
#  'name': 10,
#  'entered': 16,
#  'roll': 1,
#  'students': 1,
#  'ofthe': 29,
#  'university': 1,
#  'drank': 2,
#  'lot': 3,
#  'beer': 1,
#  'studied': 3,
#  'littlechemistry': 1,
#  'end': 10,
#  'years’': 1,
#  'probation': 1,
#  'began': 16,
#  'withapprehension': 1,
#  'father’s': 3,
#  'parting': 1,
#  'words': 27,
#  'youneedn’t': 1,
#  'back’“and': 1,
#  'day': 40,
#  'loss': 3,
#  'do': 126,
#  'receivedword': 1,
#  'died': 4,
#  'suddenly': 8,
#  'left': 44,
#  'small': 8,
#  'fortune“i': 1,
#  'dreaded': 2,
#  'beganto': 1,
#  'ask': 9,
#  'friend“this': 1,
#  'friend': 28,
#  'wizened': 2,
#  'eccentric': 2,
#  'boastful': 1,
#  'anundying': 1,
#  'enthusiasm': 7,
#  'rare': 8,
#  'beautiful': 17,
#  'spoke': 4,
#  'cunningwords': 1,
#  'entice': 1,
#  '‘your': 1,
#  'successful': 4,
#  'ofwork': 1,
#  'work–of': 1,
#  'tasks': 2,
#  'bind': 1,
#  'moreinexorably': 1,
#  'success': 6,
#  'thedirest': 1,
#  'failure': 2,
#  'safely': 2,
#  'steer': 1,
#  'onethrough': 1,
#  'minute': 8,
#  'theexcitement': 1,
#  'keen': 3,
#  'delight': 2,
#  'ecstasy': 4,
#  'live': 3,
#  'such': 24,
#  'isto': 2,
#  'machine': 2,
#  'man“‘come’': 1,
#  '‘with': 1,
#  'show': 22,
#  'whyshould': 2,
#  'hideous': 3,
#  'millions': 2,
#  'offools': 1,
#  'labor': 1,
#  'doggedly–to': 1,
#  'world': 33,
#  'agoing–why': 1,
#  'bedragged': 1,
#  'ranks': 2,
#  'slaves': 2,
#  'lash': 1,
#  'thousands': 1,
#  'toagonize': 1,
#  'strive': 2,
#  'create': 1,
#  'beautiful–and': 1,
#  'fail': 8,
#  'terribly': 1,
#  'dragged': 3,
#  'those': 32,
#  'ideal': 4,
#  'thereare': 1,
#  'hundreds': 8,
#  'make': 52,
#  'slave': 6,
#  'toconscience': 1,
#  'fine': 6,
#  'art': 4,
#  'enjoy': 5,
#  'perfectly': 6,
#  'wisely': 2,
#  'sorare': 1,
#  'vulgar': 4,
#  'exist': 3,
#  'foryou’': 1,
#  'listened': 7,
#  'am”“there': 1,
#  'about': 86,
#  'all”': 5,
#  'jacquelinewistfully': 1,
#  'there’s': 2,
#  'sophistry': 2,
#  'somewhere': 6,
#  'brutallyselfish”“sophistry': 1,
#  'selfish': 3,
#  'subtle': 5,
#  'selfishness': 1,
#  'alonecan': 1,
#  'calculationsin': 1,
#  'building': 3,
#  'fool’s': 2,
#  'paradise”“and': 1,
#  'troubled': 5,
#  'pitied': 1,
#  'me“i': 3,
#  'forgotten': 5,
#  'love”i': 1,
#  'leaned': 8,
#  'toward': 30,
#  'regardless': 1,
#  'pietro': 10,
#  'wassquinting': 1,
#  'hand“dear': 1,
#  'late': 14,
#  'beginagain”jacqueline': 1,
#  'silent': 7,
#  'withdrew': 4,
#  'gently': 7,
#  'ittremble': 1,
#  'mine“do': 1,
#  'question”': 2,
#  '“when': 5,
#  'wasin': 2,
#  'tokeep': 2,
#  'reminding': 2,
#  'before': 77,
#  'myselfan': 1,
#  'faithful': 2,
#  'ihave': 6,
#  'tried': 8,
#  'remind': 6,
#  'just': 49,
#  'strongly': 1,
#  'theworld': 4,
#  'steamboat': 1,
#  'factory–a': 1,
#  'workaday': 2,
#  'world–a': 1,
#  'relentlessworld': 1,
#  'tear': 1,
#  'rend': 2,
#  'aposition': 1,
#  'ruthless': 2,
#  'others': 7,
#  'unscrupulousoften': 1,
#  'strives': 1,
#  'madly': 1,
#  'hisreach': 1,
#  'reminded': 5,
#  'itover': 1,
#  'use': 19,
#  'can’t': 2,
#  'speakjacqueline': 1,
#  'you”she': 2,
#  'sat': 15,
#  'motionless': 4,
#  'claspedher': 1,
#  'knees': 5,
#  'didspeak': 1,
#  'decisively': 1,
#  'sounded': 3,
#  'aninexorable': 1,
#  'fate“my': 1,
#  'extraordinary': 7,
#  'rarespecimens': 1,
#  'hold': 10,
#  'impossible': 25,
#  'attainthat': 1,
#  'frankly': 3,
#  'abandon': 3,
#  'yourself': 13,
#  'materialism–a': 1,
#  'materialismthat': 1,
#  'smothers': 1,
#  'attempted': 8,
#  'isincredible': 1,
#  'deliberately': 4,
#  'lay': 10,
#  'loll': 1,
#  'aflowery': 1,
#  'ease': 3,
#  'poorworld': 1,
#  'gulf': 1,
#  'fixed': 2,
#  'between': 20,
#  'yes': 21,
#  'glory': 4,
#  'sneer': 2,
#  'qualities': 5,
#  'lackthat': 1,
#  'easy': 4,
#  'forgive': 14,
#  'weak': 2,
#  'call': 13,
#  'poor': 10,
#  'worldruthless': 1,
#  'ruthlessness': 1,
#  'unscrupulousness': 1,
#  'gowith': 1,
#  'strength': 3,
#  'touch': 4,
#  'relentlessnessyou': 1,
#  'despise': 1,
#  'unscrupulous': 3,
#  'forpatience': 1,
#  'surely': 14,
#  'greatly': 4,
#  'patient': 6,
#  'strong': 8,
#  'youmy': 1,
#  'dick': 9,
#  'area': 1,
#  'piece': 6,
#  'bricàbrac': 2,
#  'ideals': 3,
#  'youshould': 2,
#  'glass': 6,
#  'case': 15,
#  'précieux': 1,
#  'struggle': 1,
#  'inthe': 21,
#  'shrink': 1,
#  'donenothing': 1,
#  'deserve': 1,
#  'it”i': 1,
#  'could': 134,
#  'speak': 11,
#  'truth': 6,
#  'atme': 1,
#  'touched': 11,
#  'arm': 21,
#  'lightly“i': 1,
#  'hurt': 5,
#  'you”': 14,
#  'pleaded“well': 1,
#  'roughly': 2,
#  '“it': 18,
#  'jacquelineis': 1,
#  'final': 1,
#  'plunge': 1,
#  'struggle–if': 1,
#  'youthat': 2,
#  'achieve': 1,
#  'woman': 16,
#  'notfor': 1,
#  'let': 37,
#  'you”“can': 1,
#  'leopard': 1,
#  'change': 5,
#  'spots”': 1,
#  'lightly“that': 1,
#  'remains': 1,
#  'seen': 31,
#  'prove': 12,
#  'merely': 11,
#  'thedilettante': 2,
#  'surface': 4,
#  'succeedbefore': 1,
#  'perhaps': 34,
#  'nothing': 50,
#  'work': 48,
#  'forif': 1,
#  'andthink': 1,
#  'lack': 5,
#  'you”“what': 1,
#  'softly“i': 1,
#  'tomorrow': 7,
#  'join': 5,
#  'inbusiness”“to': 1,
#  'tomorrow”': 1,
#  'dismay“yes”': 1,
#  'cried': 71,
#  'joyously': 2,
#  'caught': 13,
#  'dismay“but': 1,
#  'advise': 2,
#  'take': 36,
#  'thatresponsibility': 1,
#  ...}

# %%
'''
Exercise 13.3. Modify the program from the previous exercise to print the 20 most frequently used
words in the book.

# %%
def most_frequent(x):
    l=[]
    for key in x:
        value=x[key]
        l.append((value,key))
    l=sorted(l,reverse=True)
    return l

# %%
x=most_frequent(b)

# %%
x[0:20]
# Out:
# [(1507, 'the'),
#  (719, 'and'),
#  (620, 'to'),
#  (465, 'of'),
#  (461, 'a'),
#  (296, 'he'),
#  (278, 'was'),
#  (274, 'his'),
#  (268, 'in'),
#  (237, 'that'),
#  (203, 'you'),
#  (195, 'with'),
#  (188, 'they'),
#  (176, 'her'),
#  (170, 'i'),
#  (163, 'for'),
#  (163, 'as'),
#  (161, 'not'),
#  (157, 'had'),
#  (146, 'she')]

# %%
y=most_frequent(c)
y[0:20]
# Out:
# [(3598, 'the'),
#  (1635, 'i'),
#  (1619, 'of'),
#  (1600, 'to'),
#  (1162, 'and'),
#  (1077, 'a'),
#  (862, 'that'),
#  (861, 'in'),
#  (767, 'you'),
#  (701, 'it'),
#  (697, 'was'),
#  (643, 'he'),
#  (553, 'is'),
#  (526, 'had'),
#  (502, 'my'),
#  (472, 'me'),
#  (467, 'for'),
#  (464, 'not'),
#  (453, 'at'),
#  (400, 'his')]

# %%
'''
Exercise 13.4. Modify the previous program to read a word list (see Section 9.1) and then print all
the words in the book that are not in the word list. How many of them are typos? How many of
them are common words that should be in the word list, and how many of them are really obscure?

# %%
words=[]
for lines in open('C:/Users/HP/Desktop/words.txt'):
        words.append(lines.strip())

# %%
words
# Out:
# ['aa',
#  'aah',
#  'aahed',
#  'aahing',
#  'aahs',
#  'aal',
#  'aalii',
#  'aaliis',
#  'aals',
#  'aardvark',
#  'aardvarks',
#  'aardwolf',
#  'aardwolves',
#  'aas',
#  'aasvogel',
#  'aasvogels',
#  'aba',
#  'abaca',
#  'abacas',
#  'abaci',
#  'aback',
#  'abacus',
#  'abacuses',
#  'abaft',
#  'abaka',
#  'abakas',
#  'abalone',
#  'abalones',
#  'abamp',
#  'abampere',
#  'abamperes',
#  'abamps',
#  'abandon',
#  'abandoned',
#  'abandoning',
#  'abandonment',
#  'abandonments',
#  'abandons',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasement',
#  'abasements',
#  'abaser',
#  'abasers',
#  'abases',
#  'abash',
#  'abashed',
#  'abashes',
#  'abashing',
#  'abasing',
#  'abatable',
#  'abate',
#  'abated',
#  'abatement',
#  'abatements',
#  'abater',
#  'abaters',
#  'abates',
#  'abating',
#  'abatis',
#  'abatises',
#  'abator',
#  'abators',
#  'abattis',
#  'abattises',
#  'abattoir',
#  'abattoirs',
#  'abaxial',
#  'abaxile',
#  'abbacies',
#  'abbacy',
#  'abbatial',
#  'abbe',
#  'abbes',
#  'abbess',
#  'abbesses',
#  'abbey',
#  'abbeys',
#  'abbot',
#  'abbotcies',
#  'abbotcy',
#  'abbots',
#  'abbreviate',
#  'abbreviated',
#  'abbreviates',
#  'abbreviating',
#  'abbreviation',
#  'abbreviations',
#  'abdicate',
#  'abdicated',
#  'abdicates',
#  'abdicating',
#  'abdication',
#  'abdications',
#  'abdomen',
#  'abdomens',
#  'abdomina',
#  'abdominal',
#  'abdominally',
#  'abduce',
#  'abduced',
#  'abducens',
#  'abducent',
#  'abducentes',
#  'abduces',
#  'abducing',
#  'abduct',
#  'abducted',
#  'abducting',
#  'abductor',
#  'abductores',
#  'abductors',
#  'abducts',
#  'abeam',
#  'abed',
#  'abele',
#  'abeles',
#  'abelmosk',
#  'abelmosks',
#  'aberrant',
#  'aberrants',
#  'aberration',
#  'aberrations',
#  'abet',
#  'abetment',
#  'abetments',
#  'abets',
#  'abettal',
#  'abettals',
#  'abetted',
#  'abetter',
#  'abetters',
#  'abetting',
#  'abettor',
#  'abettors',
#  'abeyance',
#  'abeyances',
#  'abeyancies',
#  'abeyancy',
#  'abeyant',
#  'abfarad',
#  'abfarads',
#  'abhenries',
#  'abhenry',
#  'abhenrys',
#  'abhor',
#  'abhorred',
#  'abhorrence',
#  'abhorrences',
#  'abhorrent',
#  'abhorrer',
#  'abhorrers',
#  'abhorring',
#  'abhors',
#  'abidance',
#  'abidances',
#  'abide',
#  'abided',
#  'abider',
#  'abiders',
#  'abides',
#  'abiding',
#  'abied',
#  'abies',
#  'abigail',
#  'abigails',
#  'abilities',
#  'ability',
#  'abioses',
#  'abiosis',
#  'abiotic',
#  'abject',
#  'abjectly',
#  'abjectness',
#  'abjectnesses',
#  'abjuration',
#  'abjurations',
#  'abjure',
#  'abjured',
#  'abjurer',
#  'abjurers',
#  'abjures',
#  'abjuring',
#  'ablate',
#  'ablated',
#  'ablates',
#  'ablating',
#  'ablation',
#  'ablations',
#  'ablative',
#  'ablatives',
#  'ablaut',
#  'ablauts',
#  'ablaze',
#  'able',
#  'ablegate',
#  'ablegates',
#  'abler',
#  'ables',
#  'ablest',
#  'ablings',
#  'ablins',
#  'abloom',
#  'abluent',
#  'abluents',
#  'ablush',
#  'abluted',
#  'ablution',
#  'ablutions',
#  'ably',
#  'abmho',
#  'abmhos',
#  'abnegate',
#  'abnegated',
#  'abnegates',
#  'abnegating',
#  'abnegation',
#  'abnegations',
#  'abnormal',
#  'abnormalities',
#  'abnormality',
#  'abnormally',
#  'abnormals',
#  'abo',
#  'aboard',
#  'abode',
#  'aboded',
#  'abodes',
#  'aboding',
#  'abohm',
#  'abohms',
#  'aboideau',
#  'aboideaus',
#  'aboideaux',
#  'aboil',
#  'aboiteau',
#  'aboiteaus',
#  'aboiteaux',
#  'abolish',
#  'abolished',
#  'abolishes',
#  'abolishing',
#  'abolition',
#  'abolitions',
#  'abolla',
#  'abollae',
#  'aboma',
#  'abomas',
#  'abomasa',
#  'abomasal',
#  'abomasi',
#  'abomasum',
#  'abomasus',
#  'abominable',
#  'abominate',
#  'abominated',
#  'abominates',
#  'abominating',
#  'abomination',
#  'abominations',
#  'aboon',
#  'aboral',
#  'aborally',
#  'aboriginal',
#  'aborigine',
#  'aborigines',
#  'aborning',
#  'abort',
#  'aborted',
#  'aborter',
#  'aborters',
#  'aborting',
#  'abortion',
#  'abortions',
#  'abortive',
#  'aborts',
#  'abos',
#  'abought',
#  'aboulia',
#  'aboulias',
#  'aboulic',
#  'abound',
#  'abounded',
#  'abounding',
#  'abounds',
#  'about',
#  'above',
#  'aboveboard',
#  'aboves',
#  'abracadabra',
#  'abradant',
#  'abradants',
#  'abrade',
#  'abraded',
#  'abrader',
#  'abraders',
#  'abrades',
#  'abrading',
#  'abrasion',
#  'abrasions',
#  'abrasive',
#  'abrasively',
#  'abrasiveness',
#  'abrasivenesses',
#  'abrasives',
#  'abreact',
#  'abreacted',
#  'abreacting',
#  'abreacts',
#  'abreast',
#  'abri',
#  'abridge',
#  'abridged',
#  'abridgement',
#  'abridgements',
#  'abridger',
#  'abridgers',
#  'abridges',
#  'abridging',
#  'abridgment',
#  'abridgments',
#  'abris',
#  'abroach',
#  'abroad',
#  'abrogate',
#  'abrogated',
#  'abrogates',
#  'abrogating',
#  'abrupt',
#  'abrupter',
#  'abruptest',
#  'abruptly',
#  'abscess',
#  'abscessed',
#  'abscesses',
#  'abscessing',
#  'abscise',
#  'abscised',
#  'abscises',
#  'abscisin',
#  'abscising',
#  'abscisins',
#  'abscissa',
#  'abscissae',
#  'abscissas',
#  'abscond',
#  'absconded',
#  'absconding',
#  'absconds',
#  'absence',
#  'absences',
#  'absent',
#  'absented',
#  'absentee',
#  'absentees',
#  'absenter',
#  'absenters',
#  'absenting',
#  'absently',
#  'absentminded',
#  'absentmindedly',
#  'absentmindedness',
#  'absentmindednesses',
#  'absents',
#  'absinth',
#  'absinthe',
#  'absinthes',
#  'absinths',
#  'absolute',
#  'absolutely',
#  'absoluter',
#  'absolutes',
#  'absolutest',
#  'absolution',
#  'absolutions',
#  'absolve',
#  'absolved',
#  'absolver',
#  'absolvers',
#  'absolves',
#  'absolving',
#  'absonant',
#  'absorb',
#  'absorbed',
#  'absorbencies',
#  'absorbency',
#  'absorbent',
#  'absorber',
#  'absorbers',
#  'absorbing',
#  'absorbingly',
#  'absorbs',
#  'absorption',
#  'absorptions',
#  'absorptive',
#  'abstain',
#  'abstained',
#  'abstainer',
#  'abstainers',
#  'abstaining',
#  'abstains',
#  'abstemious',
#  'abstemiously',
#  'abstention',
#  'abstentions',
#  'absterge',
#  'absterged',
#  'absterges',
#  'absterging',
#  'abstinence',
#  'abstinences',
#  'abstract',
#  'abstracted',
#  'abstracter',
#  'abstractest',
#  'abstracting',
#  'abstraction',
#  'abstractions',
#  'abstractly',
#  'abstractness',
#  'abstractnesses',
#  'abstracts',
#  'abstrict',
#  'abstricted',
#  'abstricting',
#  'abstricts',
#  'abstruse',
#  'abstrusely',
#  'abstruseness',
#  'abstrusenesses',
#  'abstruser',
#  'abstrusest',
#  'absurd',
#  'absurder',
#  'absurdest',
#  'absurdities',
#  'absurdity',
#  'absurdly',
#  'absurds',
#  'abubble',
#  'abulia',
#  'abulias',
#  'abulic',
#  'abundance',
#  'abundances',
#  'abundant',
#  'abundantly',
#  'abusable',
#  'abuse',
#  'abused',
#  'abuser',
#  'abusers',
#  'abuses',
#  'abusing',
#  'abusive',
#  'abusively',
#  'abusiveness',
#  'abusivenesses',
#  'abut',
#  'abutilon',
#  'abutilons',
#  'abutment',
#  'abutments',
#  'abuts',
#  'abuttal',
#  'abuttals',
#  'abutted',
#  'abutter',
#  'abutters',
#  'abutting',
#  'abuzz',
#  'abvolt',
#  'abvolts',
#  'abwatt',
#  'abwatts',
#  'aby',
#  'abye',
#  'abyed',
#  'abyes',
#  'abying',
#  'abys',
#  'abysm',
#  'abysmal',
#  'abysmally',
#  'abysms',
#  'abyss',
#  'abyssal',
#  'abysses',
#  'acacia',
#  'acacias',
#  'academe',
#  'academes',
#  'academia',
#  'academias',
#  'academic',
#  'academically',
#  'academics',
#  'academies',
#  'academy',
#  'acajou',
#  'acajous',
#  'acaleph',
#  'acalephae',
#  'acalephe',
#  'acalephes',
#  'acalephs',
#  'acanthi',
#  'acanthus',
#  'acanthuses',
#  'acari',
#  'acarid',
#  'acaridan',
#  'acaridans',
#  'acarids',
#  'acarine',
#  'acarines',
#  'acaroid',
#  'acarpous',
#  'acarus',
#  'acaudal',
#  'acaudate',
#  'acauline',
#  'acaulose',
#  'acaulous',
#  'accede',
#  'acceded',
#  'acceder',
#  'acceders',
#  'accedes',
#  'acceding',
#  'accelerate',
#  'accelerated',
#  'accelerates',
#  'accelerating',
#  'acceleration',
#  'accelerations',
#  'accelerator',
#  'accelerators',
#  'accent',
#  'accented',
#  'accenting',
#  'accentor',
#  'accentors',
#  'accents',
#  'accentual',
#  'accentuate',
#  'accentuated',
#  'accentuates',
#  'accentuating',
#  'accentuation',
#  'accentuations',
#  'accept',
#  'acceptabilities',
#  'acceptability',
#  'acceptable',
#  'acceptance',
#  'acceptances',
#  'accepted',
#  'acceptee',
#  'acceptees',
#  'accepter',
#  'accepters',
#  'accepting',
#  'acceptor',
#  'acceptors',
#  'accepts',
#  'access',
#  'accessed',
#  'accesses',
#  'accessibilities',
#  'accessibility',
#  'accessible',
#  'accessing',
#  'accession',
#  'accessions',
#  'accessories',
#  'accessory',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidentals',
#  'accidents',
#  'accidie',
#  'accidies',
#  'acclaim',
#  'acclaimed',
#  'acclaiming',
#  'acclaims',
#  'acclamation',
#  'acclamations',
#  'acclimate',
#  'acclimated',
#  'acclimates',
#  'acclimating',
#  'acclimation',
#  'acclimations',
#  'acclimatization',
#  'acclimatizations',
#  'acclimatize',
#  'acclimatizes',
#  'accolade',
#  'accolades',
#  'accommodate',
#  'accommodated',
#  'accommodates',
#  'accommodating',
#  'accommodation',
#  'accommodations',
#  'accompanied',
#  'accompanies',
#  'accompaniment',
#  'accompaniments',
#  'accompanist',
#  'accompany',
#  'accompanying',
#  'accomplice',
#  'accomplices',
#  'accomplish',
#  'accomplished',
#  'accomplisher',
#  'accomplishers',
#  'accomplishes',
#  'accomplishing',
#  'accomplishment',
#  'accomplishments',
#  'accord',
#  'accordance',
#  'accordant',
#  'accorded',
#  'accorder',
#  'accorders',
#  'according',
#  'accordingly',
#  'accordion',
#  'accordions',
#  'accords',
#  'accost',
#  'accosted',
#  'accosting',
#  'accosts',
#  'account',
#  'accountabilities',
#  'accountability',
#  'accountable',
#  'accountancies',
#  'accountancy',
#  'accountant',
#  'accountants',
#  'accounted',
#  'accounting',
#  'accountings',
#  'accounts',
#  'accouter',
#  'accoutered',
#  'accoutering',
#  'accouters',
#  'accoutre',
#  'accoutred',
#  'accoutrement',
#  'accoutrements',
#  'accoutres',
#  'accoutring',
#  'accredit',
#  'accredited',
#  'accrediting',
#  'accredits',
#  'accrete',
#  'accreted',
#  'accretes',
#  'accreting',
#  'accrual',
#  'accruals',
#  'accrue',
#  'accrued',
#  'accrues',
#  'accruing',
#  'accumulate',
#  'accumulated',
#  'accumulates',
#  'accumulating',
#  'accumulation',
#  'accumulations',
#  'accumulator',
#  'accumulators',
#  'accuracies',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'accurateness',
#  'accuratenesses',
#  'accursed',
#  'accurst',
#  'accusal',
#  'accusals',
#  'accusant',
#  'accusants',
#  'accusation',
#  'accusations',
#  'accuse',
#  'accused',
#  'accuser',
#  'accusers',
#  'accuses',
#  'accusing',
#  'accustom',
#  'accustomed',
#  'accustoming',
#  'accustoms',
#  'ace',
#  'aced',
#  'acedia',
#  'acedias',
#  'aceldama',
#  'aceldamas',
#  'acentric',
#  'acequia',
#  'acequias',
#  'acerate',
#  'acerated',
#  'acerb',
#  'acerbate',
#  'acerbated',
#  'acerbates',
#  'acerbating',
#  'acerber',
#  'acerbest',
#  'acerbic',
#  'acerbities',
#  'acerbity',
#  'acerola',
#  'acerolas',
#  'acerose',
#  'acerous',
#  'acers',
#  'acervate',
#  'acervuli',
#  'aces',
#  'acescent',
#  'acescents',
#  'aceta',
#  'acetal',
#  'acetals',
#  'acetamid',
#  'acetamids',
#  'acetate',
#  'acetated',
#  'acetates',
#  'acetic',
#  'acetified',
#  'acetifies',
#  'acetify',
#  'acetifying',
#  'acetone',
#  'acetones',
#  'acetonic',
#  'acetose',
#  'acetous',
#  'acetoxyl',
#  'acetoxyls',
#  'acetum',
#  'acetyl',
#  'acetylene',
#  'acetylenes',
#  'acetylic',
#  'acetyls',
#  'ache',
#  'ached',
#  'achene',
#  'achenes',
#  'achenial',
#  'aches',
#  'achier',
#  'achiest',
#  'achievable',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achiever',
#  'achievers',
#  'achieves',
#  'achieving',
#  'achiness',
#  'achinesses',
#  'aching',
#  'achingly',
#  'achiote',
#  'achiotes',
#  'achoo',
#  'achromat',
#  'achromats',
#  'achromic',
#  'achy',
#  'acicula',
#  'aciculae',
#  'acicular',
#  'aciculas',
#  'acid',
#  'acidhead',
#  'acidheads',
#  'acidic',
#  'acidified',
#  'acidifies',
#  'acidify',
#  'acidifying',
#  'acidities',
#  'acidity',
#  'acidly',
#  'acidness',
#  'acidnesses',
#  'acidoses',
#  'acidosis',
#  'acidotic',
#  'acids',
#  'acidy',
#  'acierate',
#  'acierated',
#  'acierates',
#  'acierating',
#  'aciform',
#  'acinar',
#  'acing',
#  'acini',
#  'acinic',
#  'acinose',
#  'acinous',
#  'acinus',
#  'acknowledge',
#  'acknowledged',
#  'acknowledgement',
#  'acknowledgements',
#  'acknowledges',
#  'acknowledging',
#  'acknowledgment',
#  'acknowledgments',
#  'aclinic',
#  'acmatic',
#  'acme',
#  'acmes',
#  'acmic',
#  'acne',
#  'acned',
#  'acnes',
#  'acnode',
#  'acnodes',
#  'acock',
#  'acold',
#  'acolyte',
#  'acolytes',
#  'aconite',
#  'aconites',
#  'aconitic',
#  'aconitum',
#  'aconitums',
#  'acorn',
#  'acorns',
#  'acoustic',
#  'acoustical',
#  'acoustically',
#  'acoustics',
#  'acquaint',
#  'acquaintance',
#  'acquaintances',
#  'acquaintanceship',
#  'acquaintanceships',
#  'acquainted',
#  'acquainting',
#  'acquaints',
#  'acquest',
#  'acquests',
#  'acquiesce',
#  'acquiesced',
#  'acquiescence',
#  'acquiescences',
#  'acquiescent',
#  'acquiescently',
#  'acquiesces',
#  'acquiescing',
#  'acquire',
#  'acquired',
#  'acquirer',
#  'acquirers',
#  'acquires',
#  'acquiring',
#  'acquisition',
#  'acquisitions',
#  'acquisitive',
#  'acquit',
#  'acquits',
#  'acquitted',
#  'acquitting',
#  'acrasin',
#  'acrasins',
#  'acre',
#  'acreage',
#  'acreages',
#  'acred',
#  'acres',
#  'acrid',
#  'acrider',
#  'acridest',
#  'acridine',
#  'acridines',
#  'acridities',
#  'acridity',
#  'acridly',
#  'acridness',
#  'acridnesses',
#  'acrimonies',
#  'acrimonious',
#  'acrimony',
#  'acrobat',
#  'acrobatic',
#  'acrobats',
#  'acrodont',
#  'acrodonts',
#  'acrogen',
#  'acrogens',
#  'acrolein',
#  'acroleins',
#  'acrolith',
#  'acroliths',
#  'acromia',
#  'acromial',
#  'acromion',
#  'acronic',
#  'acronym',
#  'acronyms',
#  'across',
#  'acrostic',
#  'acrostics',
#  'acrotic',
#  'acrotism',
#  'acrotisms',
#  'acrylate',
#  'acrylates',
#  'acrylic',
#  'acrylics',
#  'act',
#  'acta',
#  'actable',
#  'acted',
#  'actin',
#  'actinal',
#  'acting',
#  'actings',
#  'actinia',
#  'actiniae',
#  'actinian',
#  'actinians',
#  'actinias',
#  'actinic',
#  'actinide',
#  'actinides',
#  'actinism',
#  'actinisms',
#  'actinium',
#  'actiniums',
#  'actinoid',
#  'actinoids',
#  'actinon',
#  'actinons',
#  'actins',
#  'action',
#  'actions',
#  'activate',
#  'activated',
#  'activates',
#  'activating',
#  'activation',
#  'activations',
#  'active',
#  'actively',
#  'actives',
#  'activism',
#  'activisms',
#  'activist',
#  'activists',
#  'activities',
#  'activity',
#  'actor',
#  'actorish',
#  'actors',
#  'actress',
#  'actresses',
#  'acts',
#  'actual',
#  'actualities',
#  'actuality',
#  'actualization',
#  'actualizations',
#  'actualize',
#  'actualized',
#  'actualizes',
#  'actualizing',
#  'actually',
#  'actuarial',
#  'actuaries',
#  ...]

# %%
len(bear)
# Out:
# 22360

# %%
l=[]
for word in bear:
    if word not in words:
        l.append(word)

# %%
len(l)
# Out:
# 3238

# %%
l
# Out:
# ['a',
#  'seoul',
#  'korea',
#  'controlof',
#  'a',
#  'a',
#  'calledchonwathe',
#  'untilshe',
#  'accordingto',
#  'thestate',
#  'showthe',
#  'a',
#  'kingschild',
#  'countryso',
#  'noticeda',
#  'fiercelooking',
#  'a',
#  'boldman',
#  'hefollowed',
#  'whenthe',
#  'a',
#  'a',
#  'turtledovedrink',
#  'a',
#  'inhis',
#  'himbefore',
#  'twicecourageously',
#  'scratchedhis',
#  'thedefiant',
#  'inhis',
#  'armsjust',
#  'helittle',
#  'expectedhe',
#  'grinningbearthe',
#  'forhis',
#  'stillgrinning',
#  'a',
#  'onthe',
#  'outof',
#  'handthe',
#  'thesetting',
#  'tosee',
#  'turnedand',
#  'chonwawas',
#  'willinglythey',
#  'camerushing',
#  'themand',
#  'turnedand',
#  'awaychonwa',
#  'butonly',
#  'thewhole',
#  'affairthe',
#  'a',
#  'washastened',
#  'aslostthe',
#  'forher',
#  'longtill',
#  'customof',
#  'chonwa',
#  'consideredready',
#  'marriageshe',
#  'a',
#  'a',
#  'hatefulchanot',
#  'seeher',
#  'a',
#  'allthe',
#  'chonwa',
#  'deadamong',
#  'a',
#  'chonwa',
#  'consideredher',
#  'hergoverness',
#  'boyprince',
#  'mousan',
#  'werefound',
#  'chonwawas',
#  'a',
#  'herprotests',
#  'marriagearranged',
#  'korea',
#  'imaginechonwas',
#  'hamkiengwhich',
#  'a',
#  'andsnored',
#  'whenhe',
#  'a',
#  'chonwa',
#  'butshe',
#  'weddingday',
#  'arrivedthe',
#  'allassembled',
#  'begina',
#  'stoppedhis',
#  'theroom',
#  'chonwas',
#  'kingin',
#  'hammiesothey',
#  'courtdrawing',
#  'thrustat',
#  'a',
#  'headrolling',
#  'a',
#  'hadscattered',
#  'hidthe',
#  'atight',
#  'hidingplaces',
#  'moreastonished',
#  'chonwabestride',
#  'thegarden',
#  'aneighboring',
#  'forestthe',
#  'hammiechagrined',
#  'a',
#  'rewardwas',
#  'princesswas',
#  'chonwa',
#  'homemeanwhile',
#  'chonwa',
#  'ayoung',
#  'ablack',
#  'broadbrimmed',
#  'chonwa',
#  'mousan',
#  'banishedprincei',
#  'i',
#  'ihave',
#  'youbruin',
#  'hermouth',
#  'talkmy',
#  'chonwa',
#  'i',
#  'a',
#  'morebeautiful',
#  'andwork',
#  'thentrace',
#  'naktongkang',
#  'settledown',
#  'a',
#  'ourselvesbut',
#  'afunnylooking',
#  'thembraided',
#  'thumband',
#  'a',
#  'washumok',
#  'diseasesthe',
#  'chonwa',
#  'eyeswhich',
#  'slappedhis',
#  'felta',
#  'andthe',
#  'biggerand',
#  'moreshe',
#  'faintedmousan',
#  'andsmote',
#  'a',
#  'hisstone',
#  'a',
#  'girlmeanwhile',
#  'apitifullooking',
#  'bloodshot',
#  'a',
#  'myprecious',
#  'quackmouwou',
#  'terriblepaw',
#  'silentbut',
#  'mousan',
#  'herushed',
#  'offhowlingscarcely',
#  'thequack',
#  'a',
#  'theground',
#  'himfrom',
#  'helpnow',
#  'humok',
#  'anyordinary',
#  'i',
#  'a',
#  'mousan',
#  'toescape',
#  'a',
#  'itthere',
#  'lestsome',
#  'denwhen',
#  'tomount',
#  'wasanything',
#  'herwhere',
#  'mousan',
#  'thedoctorthey',
#  'a',
#  'a',
#  'littlebird',
#  'screamingand',
#  'reptileand',
#  'a',
#  'itsrescuers',
#  'itssmooth',
#  'dieso',
#  'chonwasshoulder',
#  'anddelighted',
#  'a',
#  'asign',
#  'wearydo',
#  'mousan',
#  'chonwa',
#  'shedismounted',
#  'herdelight',
#  'a',
#  'a',
#  'readingshe',
#  'a',
#  'glassof',
#  'chonwa',
#  'thedrink',
#  'a',
#  'dartedoutchonwa',
#  'fearthe',
#  'chonwa',
#  'sawher',
#  'pursueherthe',
#  'thesnake',
#  'allits',
#  'itstiny',
#  'bitingbut',
#  'chonwa',
#  'fellto',
#  'othersmouwou',
#  'smotethe',
#  'a',
#  'tofind',
#  'onfinally',
#  'a',
#  'a',
#  'thatgurgled',
#  'a',
#  'a',
#  'goodmother',
#  'a',
#  'herto',
#  'sleepwhen',
#  'chonwa',
#  'aboutmousanthe',
#  'shesaid',
#  'afraidill',
#  'thisspot',
#  'shelumbered',
#  'sightno',
#  'bearmother',
#  'camecrawling',
#  'i',
#  'andi',
#  'i',
#  'thebirds',
#  'a',
#  'deathstareoh',
#  'chonwa',
#  'thebird',
#  'quicklyat',
#  'a',
#  'mushroomsmushrooms',
#  'i',
#  'canhelp',
#  'deliciouschonwa',
#  'a',
#  'feettall',
#  'a',
#  'littlechoirboy',
#  'a',
#  'a',
#  'hotand',
#  'afragrance',
#  'chonwas',
#  'waterbut',
#  'afraidwho',
#  'chonwai',
#  'a',
#  'i',
#  'yourfather',
#  'a',
#  'i',
#  'cookingfor',
#  'littlebird',
#  'medicinewith',
#  'chonwas',
#  'a',
#  'birdsthroat',
#  'withdelightnevertheless',
#  'thesnakewomans',
#  'turnedinto',
#  'asan',
#  'lawsof',
#  'asfine',
#  'soonshe',
#  'heelsin',
#  'i',
#  'beenpromised',
#  'a',
#  'evilwoman',
#  'lifeha',
#  'i',
#  'notclever',
#  'i',
#  'gettingstraight',
#  'mouwou',
#  'tonguehung',
#  'foamher',
#  'thunderthe',
#  'hishair',
#  'outyes',
#  'shelifted',
#  'thehumpouch',
#  'thrustout',
#  'humpchested',
#  'nowthere',
#  'youll',
#  'wonthave',
#  'morewhile',
#  'mouwou',
#  'furiouslypicking',
#  'chonwas',
#  'a',
#  'holewas',
#  'a',
#  'inthe',
#  'mouwou',
#  'armseveral',
#  'shescratched',
#  'killedthe',
#  'mothermade',
#  'a',
#  'a',
#  'forthe',
#  'mousan',
#  'chonwa',
#  'asleepin',
#  'alittle',
#  'informationthat',
#  'thebird',
#  'chonwa',
#  'groundapparently',
#  'twistedround',
#  'a',
#  'beforehe',
#  'overtrying',
#  'waswhen',
#  'himill',
#  'isall',
#  'wantso',
#  'wasreally',
#  'backwardthe',
#  'walkbut',
#  'usualway',
#  'hewas',
#  'a',
#  'nosepointed',
#  'downhe',
#  'wayopposite',
#  'hewent',
#  'treeinstead',
#  'inhis',
#  'neckoh',
#  'i',
#  'a',
#  'ideserve',
#  'a',
#  'i',
#  'inthe',
#  'i',
#  'neveri',
#  'forit',
#  'painthe',
#  'approvingly',
#  'thebear',
#  'headto',
#  'greatwhack',
#  'a',
#  'againthe',
#  'snakewoman',
#  'nowthat',
#  'a',
#  'tothe',
#  'wherethe',
#  'livedthey',
#  'mousan',
#  'timelay',
#  'a',
#  'haddeposited',
#  'preciousstone',
#  'caveentering',
#  'a',
#  'thathe',
#  'movethe',
#  'a',
#  'towardhim',
#  'histobacco',
#  'a',
#  'backslowly',
#  'hismouth',
#  'theair',
#  'angerhe',
#  'backat',
#  'a',
#  'afew',
#  'helaughed',
#  'facefinally',
#  'boyyou',
#  'mousan',
#  'ishall',
#  'silencedfrom',
#  'theprinces',
#  'a',
#  'witheyes',
#  'nightat',
#  'ihave',
#  'arton',
#  'onearth',
#  'i',
#  'a',
#  'atthe',
#  'i',
#  'a',
#  'ofhimself',
#  'i',
#  'wayi',
#  'thenews',
#  'i',
#  'throwa',
#  'a',
#  'squirmcome',
#  'i',
#  'stonefreed',
#  'andstretched',
#  'proposalvery',
#  'theprinces',
#  'a',
#  'a',
#  'a',
#  'foughtthem',
#  'thenipping',
#  'a',
#  'hisend',
#  'deaththe',
#  'ofhis',
#  'toenjoy',
#  'victimsuddenly',
#  'bearstaggering',
#  'a',
#  'thebear',
#  'himout',
#  'woundsin',
#  'a',
#  'ofthe',
#  'froma',
#  'mousans',
#  'limbsmikado',
#  'i',
#  'hismagic',
#  'i',
#  'theboy',
#  'magicin',
#  'a',
#  'glisteningstone',
#  'wellagain',
#  'mousan',
#  'stonethey',
#  'mousan',
#  'couldscarcely',
#  'chonwa',
#  'waswith',
#  'himthen',
#  'mouwou',
#  'embracei',
#  'i',
#  'canspeak',
#  'thelaw',
#  'a',
#  'endall',
#  'enduredhas',
#  'forgetthe',
#  'i',
#  'andby',
#  'thatmiserable',
#  'i',
#  'a',
#  'q',
#  'quackso',
#  'tothe',
#  'countrythe',
#  'andjoy',
#  'bearthe',
#  'livedvery',
#  'findwritten',
#  'koreathe',
#  'witchin',
#  'a',
#  'a',
#  'whoformerly',
#  'didthis',
#  'moresad',
#  'naughtyone',
#  'pleaseanybody',
#  'thetime',
#  'hermother',
#  'bedimmediately',
#  'supperas',
#  'hadnot',
#  'butmuttered',
#  'a',
#  'i',
#  'thewicked',
#  'i',
#  'anywayno',
#  'a',
#  'flashedupon',
#  'horrorcoming',
#  'wildeyed',
#  'grayand',
#  'a',
#  'stickpolly',
#  'squeakof',
#  'a',
#  'motherbut',
#  'a',
#  'a',
#  'camenearer',
#  'uglypolly',
#  'womando',
#  'outof',
#  'ahideous',
#  'pouterin',
#  'nightdress',
#  'shefollowed',
#  'andthe',
#  'a',
#  'thewitch',
#  'thenshe',
#  'stoppedand',
#  'wishpoor',
#  'speakask',
#  'pollyshaking',
#  'i',
#  'decidegoinggoinggoneat',
#  'makingsparks',
#  'flypolly',
#  'i',
#  'pleasethen',
#  'a',
#  'becamedark',
#  'untilsuddenly',
#  'a',
#  'beensomebody',
#  'elseoh',
#  'aboutand',
#  'laywas',
#  'faroff',
#  'a',
#  'a',
#  'andlovely',
#  'allmeanthe',
#  'midheaven',
#  'pollys',
#  'couldsee',
#  'andsquirrels',
#  'nutsthen',
#  'moreyoungsters',
#  'a',
#  'meadowwhen',
#  'verywelcome',
#  'themfinally',
#  'a',
#  'isdinnertime',
#  'saidpolly',
#  'a',
#  'tallstately',
#  'clocktower',
#  'ofthe',
#  'twelveoh',
#  'isnt',
#  'didnt',
#  'i',
#  'itbeforebecause',
#  'timeat',
#  'a',
#  'sweetchant',
#  'madeher',
#  'a',
#  'ofearth',
#  'childrento',
#  'towerhow',
#  'pollyit',
#  'hourhow',
#  'i',
#  'beforedo',
#  'themorning',
#  'wechildren',
#  'a',
#  'timeswe',
#  'musicthe',
#  'abouther',
#  'laughpolly',
#  'whereuponthe',
#  'offharry',
#  'hepleaded',
#  'betterpolly',
#  'i',
#  'aboutme',
#  'a',
#  'tattletaleshe',
#  'walkedaway',
#  'sadlysuddenly',
#  'wassorry',
#  'tofind',
#  'clocktower',
#  'beafraid',
#  'a',
#  'herselfdead',
#  'pollywas',
#  'sadbut',
#  'shesaw',
#  'whenpolly',
#  'shecould',
#  'spotoh',
#  'kneesdont',
#  'i',
#  'i',
#  'i',
#  'willtry',
#  'pleasedont',
#  'awayinstead',
#  'gentlypatted',
#  'noone',
#  'stubbornill',
#  'goodill',
#  'pollythen',
#  'womandisappearing',
#  'sceneas',
#  'wishedfor',
#  'muchexcitement',
#  'dreamlandshe',
#  'harrys',
#  'voicepolly',
#  'blueeyes',
#  'dinnertime',
#  'hurrythere',
#  'eatoh',
#  'i',
#  'naughtyhappily',
#  'becomevisible',
#  'changedwith',
#  'sawsnakes',
#  'wasgood',
#  'beautifulobjectswhen',
#  'leavingpolly',
#  'a',
#  'thingson',
#  'tableafter',
#  'herits',
#  'apicture',
#  'a',
#  'twochildren',
#  'afteroh',
#  'thegray',
#  'runshe',
#  'insurprise',
#  'youknew',
#  'shewho',
#  'dinneri',
#  'horridi',
#  'sheis',
#  'meyou',
#  'theworldpolly',
#  'girlwas',
#  'a',
#  'thewitch',
#  'smilingwhy',
#  'thelittle',
#  'i',
#  'looklike',
#  'beforeit',
#  'a',
#  'a',
#  'mirroroh',
#  'oldwoman',
#  'thetwo',
#  'alonei',
#  'i',
#  'exclaimedthey',
#  'a',
#  'roada',
#  'gabblingsomething',
#  'mylittle',
#  'therepolly',
#  'motherwith',
#  'werethe',
#  'assoon',
#  'andcradled',
#  'dofor',
#  'tillthey',
#  'a',
#  'a',
#  'idlechildren',
#  'youngstersi',
#  'a',
#  'repliedpolly',
#  'i',
#  'i',
#  'i',
#  'wasmistaken',
#  'i',
#  'childrenwhen',
#  'halfmile',
#  'thebig',
#  'bullfrogsnow',
#  'youwill',
#  'ofthe',
#  'likeother',
#  'a',
#  'thepeople',
#  'frogdom',
#  'impressedsure',
#  'a',
#  'littlethey',
#  'a',
#  'whowas',
#  'a',
#  'a',
#  'twigimmediately',
#  'upit',
#  'a',
#  'bassup',
#  'a',
#  'waterso',
#  'a',
#  'delightful',
#  'theirtoes',
#  'a',
#  'violineffect',
#  'likepiccolosthe',
#  'thefrog',
#  'keepingtime',
#  'theyknew',
#  'a',
#  'aboutthe',
#  'joinedtogethersuddenly',
#  'a',
#  'bullfrogsitting',
#  'a',
#  'carof',
#  'islandit',
#  'harrythe',
#  'a',
#  'offroggies',
#  'bandstruck',
#  'frogdom',
#  'andwaved',
#  'hismajesty',
#  'wonderfultime',
#  'itlongestthe',
#  'frogking',
#  'ofthemselves',
#  'i',
#  'betterable',
#  'shedeclared',
#  'islandas',
#  'wasaddressing',
#  'theirastonishment',
#  'hissingloudly',
#  'andhis',
#  'waterthe',
#  'byhis',
#  'hisbereaved',
#  'a',
#  'theysaw',
#  'thegoosemrs',
#  'hissedwhat',
#  'a',
#  'ownstupidity',
#  'i',
#  'moremonarchs',
#  'i',
#  'sosaying',
#  'bridgeafter',
#  'andpaddled',
#  'littlefishes',
#  'heightthey',
#  'a',
#  'a',
#  'littleboat',
#  'theblade',
#  'a',
#  'hiswee',
#  'cockleshellget',
#  'i',
#  'thegreat',
#  'palacebut',
#  'bodynothing',
#  'boatmanso',
#  'a',
#  'littleout',
#  'a',
#  'boatmanplied',
#  'a',
#  'thesurface',
#  'themost',
#  'delightful',
#  'takenjust',
#  'a',
#  'ita',
#  'a',
#  'buildingstood',
#  'thechildren',
#  'a',
#  'meetthem',
#  'wereplaying',
#  'foryearsby',
#  'a',
#  'pollys',
#  'wanderedto',
#  'higheightsided',
#  'itssides',
#  'bellshaped',
#  'metalssomeof',
#  'thesetting',
#  'descriptionwhat',
#  'andpointing',
#  'castlethat',
#  'isrepeated',
#  'heardsinging',
#  'growsthey',
#  'townclock',
#  'theycounted',
#  'strokesone',
#  'manymiles',
#  'awayit',
#  'pollythe',
#  'athousand',
#  'beautifulmusic',
#  'grandharmonies',
#  'heavenwhen',
#  'manyminutes',
#  'themand',
#  'returnedwell',
#  'methen',
#  'a',
#  'haghad',
#  'a',
#  'womanyou',
#  'i',
#  'feelingbetter',
#  'i',
#  'thoughtspeople',
#  'desirethat',
#  'trulydesire',
#  'crippledor',
#  'sodesire',
#  'a',
#  'butterflyand',
#  'baggednow',
#  'factshe',
#  'a',
#  'thewoman',
#  'butthe',
#  'shewas',
#  'hadbeen',
#  'a',
#  'agonow',
#  'i',
#  'shallhave',
#  'i',
#  'believeyou',
#  'sakeplease',
#  'ishall',
#  'i',
#  'becausei',
#  'i',
#  'myselfillustration',
#  'eleanor',
#  'howardpolly',
#  'thathour',
#  'womanexplained',
#  'towerthat',
#  'millionsand',
#  'thesoundreceivers',
#  'madesweeter',
#  'condensers',
#  'musicalnote',
#  'doneis',
#  'reechoeddid',
#  'wickedprayer',
#  'wasthinking',
#  'thoughtsyes',
#  'herebut',
#  'a',
#  'athousand',
#  'issaid',
#  'speakerand',
#  'toearth',
#  'andexamined',
#  'againthen',
#  'a',
#  'andasked',
#  'listenoh',
#  'i',
#  'a',
#  'wordyes',
#  'thebells',
#  'wouldnot',
#  'greatsteepleshe',
#  'aqueerlooking',
#  'a',
#  'aribbon',
#  'a',
#  'spoolthis',
#  'inthe',
#  'tunethey',
#  'spoolsslowly',
#  'a',
#  'eachindividual',
#  'waslaid',
#  'aboveisnt',
#  'i',
#  'spooldear',
#  'motherthe',
#  'herown',
#  'lifespool',
#  'itand',
#  'i',
#  'wishthat',
#  'i',
#  'thespool',
#  'wordsdo',
#  'looknow',
#  'thespool',
#  'willbe',
#  'andheld',
#  'tenderlyat',
#  'criedgoodie',
#  'goodieit',
#  'rubbedher',
#  'mammawhere',
#  'harryher',
#  'herlittle',
#  'dearshe',
#  'soonmr',
#  'roosterin',
#  'a',
#  'a',
#  'youcould',
#  'asthey',
#  'doone',
#  'mrs',
#  'a',
#  'onthe',
#  'mrs',
#  'wordsdo',
#  'i',
#  'a',
#  'winklast',
#  'nightjust',
#  'a',
#  'a',
#  'browniereturnedbrownie',
#  'husbandthe',
#  'andexchanging',
#  'layingan',
#  'thehens',
#  'ofhimself',
#  'truththe',
#  'sofunnythe',
#  'thoughtthat',
#  'alwaysfatal',
#  'redpepper',
#  'wererolling',
#  'fencealmost',
#  'offbut',
#  'cayennepepper',
#  'aboutmadly',
#  'andgasped',
#  'troughduring',
#  'possibleand',
#  'thickhead',
#  'wivesoh',
#  'intheir',
#  'beenagreed',
#  'asnorer',
#  'a',
#  'nightall',
#  'oclock',
#  'roosteropened',
#  'cockadoodledoooothis',
#  'a',
#  'burstof',
#  'neverthelessthe',
#  'alonesnoring',
#  'wiselythey',
#  'oneoclock',
#  'delightedfor',
#  'morningwhen',
#  'hissnoring',
#  'theday',
#  ...]

# %%
'''
13.2 Random numbers

# %%
#The function random returns a random float between 0.0 and 1.0 (including 0.0 but not 1.0)
import random
for i in range(10):
    x = random.random()
    print(x)
# Out:
# 0.13745756170866863
# 0.98787972219696
# 0.06265897302168932
# 0.7545244856016984
# 0.36830822424242693
# 0.385012776069802
# 0.6643116965512418
# 0.4402409236938869
# 0.4101903169775787
# 0.679167350810576

# %%
random.randint(5, 10)#tThe function randint takes parameters low and high and returns an integer between low
#and high (including both).
# Out:
# 7

# %%
t = [1, 2, 3]#tp choose from a sequence at random
random.choice(t)
# Out:
# 3

# %%
'''
Exercise 13.5. Write a function named choose_from_hist that takes a histogram as defined in
Section 11.2 and returns a random value from the histogram, chosen with probability in proportion
to frequency. For example, for this histogram:

# %%
def histogram(a):
    d=dict()
    for i in a:
        if i not in d:
            d[i]=1
        else:
            d[i]+=1
    return d

# %%
x=histogram(['a','a','b'])
x
# Out:
# {'a': 2, 'b': 1}

# %%
def choose_from_hist(hist):
    l=[]
    for key in hist:
        for i in range(hist[key]):
            l.append(key)
    return random.choice(l)

# %%
choose_from_hist(x)
# Out:
# 'b'

# %%
x.items()
# Out:
# dict_items([('a', 2), ('b', 1)])

# %%
def random_word(h):
    t = []
    for word, freq in h.items():
        t.extend([word] * freq)#The expression [word] * freq creates a list with freq copies of the string word. The
#extend method is similar to append except that the argument is a sequence.
    return random.choice(t)

# %%
random_word(x)
# Out:
# 'a'

# %%
#13.3 Word histogram

# %%
#13.5 Optional parameters
'''
def print_most_common(hist, num=10):
    t = most_common(hist)
    print('The most common words are:')
    for freq, word in t[:num]:
         print(word, freq, sep='\t')

print_most_common(hist)
print_most_common(hist, 20)

# %%
#13.8 Markov analysis

# %%
'''
1. Write a program to read a text from a file and perform Markov analysis. The result should be
a dictionary that maps from prefixes to a collection of possible suffixes. The collection might
be a list, tuple, or dictionary; it is up to you to make an appropriate choice. You can test your
program with prefix length two, but you should write the program in a way that makes it easy
to try other lengths.

# %%
def markov(x,prefix=2):
    words=convert_words(x)
    d=dict()
    for i in range(len(words)-prefix):
        x=words[i]
        for j in range(prefix-1):
            x+=' '+words[i+j+1]
        if x not in d:
            d[x]=[words[i+prefix]]
        else:
            d[x].append(words[i+prefix])
    return d

# %%
markv=markov('C:/Users/HP/Desktop/markov.txt',prefix=2)
markv
# Out:
# {'a bee': ['philosophicallymust', 'be'],
#  'a beedue': ['to'],
#  'a vis': ['its'],
#  'an entire': ['beewhen'],
#  'be an': ['entire'],
#  'be said': ['to'],
#  'bebut half': ['the'],
#  'bee be': ['said'],
#  'bee has': ['got'],
#  'bee is': ['not'],
#  'bee philosophicallymust': ['ipso'],
#  'beedue to': ['some'],
#  'beewhen half': ['the'],
#  'beor not': ['to'],
#  'bevis a': ['vis'],
#  'can a': ['bee'],
#  'd’you seebut': ['can'],
#  'entire beewhen': ['half'],
#  'entity d’you': ['seebut'],
#  'facto half': ['not'],
#  'got to': ['bevis'],
#  'half a': ['bee'],
#  'half not': ['bebut'],
#  'half the': ['bee', 'bee'],
#  'has got': ['to'],
#  'ipso facto': ['half'],
#  'is not': ['a'],
#  'its entity': ['d’you'],
#  'not a': ['beedue'],
#  'not bebut': ['half'],
#  'not to': ['be'],
#  'philosophicallymust ipso': ['facto'],
#  'said to': ['beor'],
#  'seebut can': ['a'],
#  'some ancient': ['injury'],
#  'the bee': ['has', 'is'],
#  'to be': ['an'],
#  'to beor': ['not'],
#  'to bevis': ['a'],
#  'to some': ['ancient'],
#  'vis its': ['entity']}

# %%
'''
2. Add a function to the previous program to generate random text based on the Markov analysis.
Here is an example from Emma with prefix length 2:
He was very clever, be it sweetness or be angry, ashamed or only amused, at such
a stroke. She had never thought of Hannah till you were never meant for me?" "I
cannot make speeches, Emma:" he soon cut it all himself.
For this example, I left the punctuation attached to the words. The result is almost syntactically
correct, but not quite. Semantically, it almost makes sense, but not quite.
What happens if you increase the prefix length? Does the random text make more sense?

# %%
import random
def markov_text(x,prefix=2,length=10,word='a'+' '+'b'):
    words=convert_words(x)
    d=dict()
    for i in range(len(words)-prefix):
        x=words[i]
        for j in range(prefix-1):
            x+=' '+words[i+j+1]
        if x not in d:
            d[x]=[words[i+prefix]]
        else:
            d[x].append(words[i+prefix])
    x = word+' '+random.choice(d[word])
    for i in range(length):
        y = x.split()
        x +=' '+random.choice(d[y[len(y)-2]+' '+y[len(y)-1]])
    return x

# %%
markov_text('C:/Users/HP/Desktop/ema.txt',prefix=2,length=100,word='he was')
# Out:
# 'he was sure she intended to give up musicbut you who have never been quite an invalid of that would entirely destroy my comfortyou must promise me not half done about harriet smith may not quite enter into our feelingsi know nothing of it at least forthe present with jane fairfax mistressof the abbeyoh no noevery feeling revolts for his temper and happiness his recollection of it now and then it came out again now do not imagine that you are so reasonable and thereforenot a blind to their father is to join me here is my sister has never excited agreater interest'
